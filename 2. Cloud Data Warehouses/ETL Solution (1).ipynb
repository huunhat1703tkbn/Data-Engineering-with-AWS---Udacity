# %% [markdown]
# # Demo 01 -  Sakila Star Schema & ETL
#
# All the database tables in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://video.udacity-data.com/topher/2021/August/61120e06_pagila-3nf/pagila-3nf.png)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](https://video.udacity-data.com/topher/2021/August/61120d38_pagila-star/pagila-star.png)

# %% [markdown]
# # STEP0: Using ipython-sql
#
# - load ipython-sql: `%load_ext sql`
#
# - To execute SQL queries you write one of the following atop of your cell:
#     - `%sql`
#         - For a one-liner SQL query
#         - You can access a python var using `$`
#     - `%%sql`
#         - For a multi-line SQL query
#         - You can **NOT** access a python var using `$`
#
#
# - Running a connection string like:
# `postgresql://postgres:postgres@db:5432/pagila` connects to the database

# %% [markdown]
# # STEP1 : Connect to the local database where Pagila is loaded

# %% [markdown]
# ##  1.1 Create the pagila db and fill it with data
# - Adding `"!"` at the beginning of a jupyter cell runs a command in a shell, i.e. we are not running python code but we are running the `createdb` and `psql` postgresql commmand-line utilities

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-schema.sql
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-data.sql
# Out:
# createdb: database creation failed: ERROR:  database "pagila" already exists
# psql:Data/pagila-schema.sql:43: ERROR:  type "mpaa_rating" already exists
# psql:Data/pagila-schema.sql:53: ERROR:  type "year" already exists
# psql:Data/pagila-schema.sql:70: ERROR:  function "_group_concat" already exists with same argument types
# psql:Data/pagila-schema.sql:87: ERROR:  function "film_in_stock" already exists with same argument types
# psql:Data/pagila-schema.sql:104: ERROR:  function "film_not_in_stock" already exists with same argument types
# psql:Data/pagila-schema.sql:149: ERROR:  function "get_customer_balance" already exists with same argument types
# psql:Data/pagila-schema.sql:171: ERROR:  function "inventory_held_by_customer" already exists with same argument types
# psql:Data/pagila-schema.sql:208: ERROR:  function "inventory_in_stock" already exists with same argument types
# psql:Data/pagila-schema.sql:226: ERROR:  function "last_day" already exists with same argument types
# psql:Data/pagila-schema.sql:241: ERROR:  function "last_updated" already exists with same argument types
# psql:Data/pagila-schema.sql:255: ERROR:  relation "customer_customer_id_seq" already exists
# psql:Data/pagila-schema.sql:279: ERROR:  relation "customer" already exists
# psql:Data/pagila-schema.sql:343: ERROR:  function "rewards_report" already exists with same argument types
# psql:Data/pagila-schema.sql:355: ERROR:  function "group_concat" already exists with same argument types
# psql:Data/pagila-schema.sql:369: ERROR:  relation "actor_actor_id_seq" already exists
# psql:Data/pagila-schema.sql:383: ERROR:  relation "actor" already exists
# psql:Data/pagila-schema.sql:397: ERROR:  relation "category_category_id_seq" already exists
# psql:Data/pagila-schema.sql:410: ERROR:  relation "category" already exists
# psql:Data/pagila-schema.sql:424: ERROR:  relation "film_film_id_seq" already exists
# psql:Data/pagila-schema.sql:448: ERROR:  relation "film" already exists
# psql:Data/pagila-schema.sql:461: ERROR:  relation "film_actor" already exists
# psql:Data/pagila-schema.sql:474: ERROR:  relation "film_category" already exists
# psql:Data/pagila-schema.sql:497: ERROR:  relation "actor_info" already exists
# psql:Data/pagila-schema.sql:511: ERROR:  relation "address_address_id_seq" already exists
# psql:Data/pagila-schema.sql:529: ERROR:  relation "address" already exists
# psql:Data/pagila-schema.sql:543: ERROR:  relation "city_city_id_seq" already exists
# psql:Data/pagila-schema.sql:557: ERROR:  relation "city" already exists
# psql:Data/pagila-schema.sql:571: ERROR:  relation "country_country_id_seq" already exists
# psql:Data/pagila-schema.sql:584: ERROR:  relation "country" already exists
# psql:Data/pagila-schema.sql:609: ERROR:  relation "customer_list" already exists
# psql:Data/pagila-schema.sql:632: ERROR:  relation "film_list" already exists
# psql:Data/pagila-schema.sql:646: ERROR:  relation "inventory_inventory_id_seq" already exists
# psql:Data/pagila-schema.sql:660: ERROR:  relation "inventory" already exists
# psql:Data/pagila-schema.sql:674: ERROR:  relation "language_language_id_seq" already exists
# psql:Data/pagila-schema.sql:687: ERROR:  relation "language" already exists
# psql:Data/pagila-schema.sql:710: ERROR:  relation "nicer_but_slower_film_list" already exists
# psql:Data/pagila-schema.sql:724: ERROR:  relation "payment_payment_id_seq" already exists
# psql:Data/pagila-schema.sql:740: ERROR:  relation "payment" already exists
# psql:Data/pagila-schema.sql:751: ERROR:  relation "rental_rental_id_seq" already exists
# psql:Data/pagila-schema.sql:768: ERROR:  relation "rental" already exists
# psql:Data/pagila-schema.sql:787: ERROR:  relation "sales_by_film_category" already exists
# psql:Data/pagila-schema.sql:801: ERROR:  relation "staff_staff_id_seq" already exists
# psql:Data/pagila-schema.sql:822: ERROR:  relation "staff" already exists
# psql:Data/pagila-schema.sql:836: ERROR:  relation "store_store_id_seq" already exists
# psql:Data/pagila-schema.sql:850: ERROR:  relation "store" already exists
# psql:Data/pagila-schema.sql:872: ERROR:  relation "sales_by_store" already exists
# psql:Data/pagila-schema.sql:893: ERROR:  relation "staff_list" already exists
# psql:Data/pagila-schema.sql:903: ERROR:  multiple primary keys for table "actor" are not allowed
# psql:Data/pagila-schema.sql:911: ERROR:  multiple primary keys for table "address" are not allowed
# psql:Data/pagila-schema.sql:919: ERROR:  multiple primary keys for table "category" are not allowed
# psql:Data/pagila-schema.sql:927: ERROR:  multiple primary keys for table "city" are not allowed
# psql:Data/pagila-schema.sql:935: ERROR:  multiple primary keys for table "country" are not allowed
# psql:Data/pagila-schema.sql:944: ERROR:  multiple primary keys for table "film_actor" are not allowed
# psql:Data/pagila-schema.sql:952: ERROR:  multiple primary keys for table "film_category" are not allowed
# psql:Data/pagila-schema.sql:960: ERROR:  multiple primary keys for table "film" are not allowed
# psql:Data/pagila-schema.sql:968: ERROR:  multiple primary keys for table "inventory" are not allowed
# psql:Data/pagila-schema.sql:976: ERROR:  multiple primary keys for table "language" are not allowed
# psql:Data/pagila-schema.sql:984: ERROR:  multiple primary keys for table "rental" are not allowed
# psql:Data/pagila-schema.sql:992: ERROR:  multiple primary keys for table "staff" are not allowed
# psql:Data/pagila-schema.sql:1000: ERROR:  multiple primary keys for table "store" are not allowed
# psql:Data/pagila-schema.sql:1007: ERROR:  relation "film_fulltext_idx" already exists
# psql:Data/pagila-schema.sql:1014: ERROR:  relation "idx_actor_last_name" already exists
# psql:Data/pagila-schema.sql:1021: ERROR:  relation "idx_fk_address_id" already exists
# psql:Data/pagila-schema.sql:1028: ERROR:  relation "idx_fk_city_id" already exists
# psql:Data/pagila-schema.sql:1035: ERROR:  relation "idx_fk_country_id" already exists
# psql:Data/pagila-schema.sql:1042: ERROR:  relation "idx_fk_customer_id" already exists
# psql:Data/pagila-schema.sql:1049: ERROR:  relation "idx_fk_film_id" already exists
# psql:Data/pagila-schema.sql:1056: ERROR:  relation "idx_fk_inventory_id" already exists
# psql:Data/pagila-schema.sql:1063: ERROR:  relation "idx_fk_language_id" already exists
# psql:Data/pagila-schema.sql:1070: ERROR:  relation "idx_fk_original_language_id" already exists
# psql:Data/pagila-schema.sql:1077: ERROR:  relation "idx_fk_payment_customer_id" already exists
# psql:Data/pagila-schema.sql:1083: ERROR:  relation "idx_fk_payment_staff_id" already exists
# psql:Data/pagila-schema.sql:1092: ERROR:  relation "idx_fk_store_id" already exists
# psql:Data/pagila-schema.sql:1099: ERROR:  relation "idx_last_name" already exists
# psql:Data/pagila-schema.sql:1106: ERROR:  relation "idx_store_id_film_id" already exists
# psql:Data/pagila-schema.sql:1113: ERROR:  relation "idx_title" already exists
# psql:Data/pagila-schema.sql:1120: ERROR:  relation "idx_unq_manager_staff_id" already exists
# psql:Data/pagila-schema.sql:1127: ERROR:  relation "idx_unq_rental_rental_date_inventory_id_customer_id" already exists
# psql:Data/pagila-schema.sql:1133: ERROR:  trigger "film_fulltext_trigger" for relation "film" already exists
# psql:Data/pagila-schema.sql:1140: ERROR:  trigger "last_updated" for relation "actor" already exists
# psql:Data/pagila-schema.sql:1147: ERROR:  trigger "last_updated" for relation "address" already exists
# psql:Data/pagila-schema.sql:1154: ERROR:  trigger "last_updated" for relation "category" already exists
# psql:Data/pagila-schema.sql:1161: ERROR:  trigger "last_updated" for relation "city" already exists
# psql:Data/pagila-schema.sql:1168: ERROR:  trigger "last_updated" for relation "country" already exists
# psql:Data/pagila-schema.sql:1175: ERROR:  trigger "last_updated" for relation "customer" already exists
# psql:Data/pagila-schema.sql:1182: ERROR:  trigger "last_updated" for relation "film" already exists
# psql:Data/pagila-schema.sql:1189: ERROR:  trigger "last_updated" for relation "film_actor" already exists
# psql:Data/pagila-schema.sql:1196: ERROR:  trigger "last_updated" for relation "film_category" already exists
# psql:Data/pagila-schema.sql:1203: ERROR:  trigger "last_updated" for relation "inventory" already exists
# psql:Data/pagila-schema.sql:1210: ERROR:  trigger "last_updated" for relation "language" already exists
# psql:Data/pagila-schema.sql:1217: ERROR:  trigger "last_updated" for relation "rental" already exists
# psql:Data/pagila-schema.sql:1224: ERROR:  trigger "last_updated" for relation "staff" already exists
# psql:Data/pagila-schema.sql:1231: ERROR:  trigger "last_updated" for relation "store" already exists
# psql:Data/pagila-schema.sql:1239: ERROR:  constraint "address_city_id_fkey" for relation "address" already exists
# psql:Data/pagila-schema.sql:1247: ERROR:  constraint "city_country_id_fkey" for relation "city" already exists
# psql:Data/pagila-schema.sql:1255: ERROR:  constraint "customer_address_id_fkey" for relation "customer" already exists
# psql:Data/pagila-schema.sql:1263: ERROR:  constraint "customer_store_id_fkey" for relation "customer" already exists
# psql:Data/pagila-schema.sql:1271: ERROR:  constraint "film_actor_actor_id_fkey" for relation "film_actor" already exists
# psql:Data/pagila-schema.sql:1279: ERROR:  constraint "film_actor_film_id_fkey" for relation "film_actor" already exists
# psql:Data/pagila-schema.sql:1287: ERROR:  constraint "film_category_category_id_fkey" for relation "film_category" already exists
# psql:Data/pagila-schema.sql:1295: ERROR:  constraint "film_category_film_id_fkey" for relation "film_category" already exists
# psql:Data/pagila-schema.sql:1303: ERROR:  constraint "film_language_id_fkey" for relation "film" already exists
# psql:Data/pagila-schema.sql:1311: ERROR:  constraint "film_original_language_id_fkey" for relation "film" already exists
# psql:Data/pagila-schema.sql:1319: ERROR:  constraint "inventory_film_id_fkey" for relation "inventory" already exists
# psql:Data/pagila-schema.sql:1327: ERROR:  constraint "inventory_store_id_fkey" for relation "inventory" already exists
# psql:Data/pagila-schema.sql:1334: ERROR:  constraint "rental_customer_id_fkey" for relation "rental" already exists
# psql:Data/pagila-schema.sql:1342: ERROR:  constraint "rental_inventory_id_fkey" for relation "rental" already exists
# psql:Data/pagila-schema.sql:1350: ERROR:  constraint "rental_staff_id_fkey" for relation "rental" already exists
# psql:Data/pagila-schema.sql:1358: ERROR:  constraint "staff_address_id_fkey" for relation "staff" already exists
# psql:Data/pagila-schema.sql:1366: ERROR:  constraint "staff_store_id_fkey" for relation "staff" already exists
# psql:Data/pagila-schema.sql:1374: ERROR:  constraint "store_address_id_fkey" for relation "store" already exists
# psql:Data/pagila-schema.sql:1384: ERROR:  constraint "payment_customer_id_fkey" for relation "payment" already exists
# psql:Data/pagila-data.sql:224: ERROR:  duplicate key value violates unique constraint "actor_pkey"
# DETAIL:  Key (actor_id)=(1) already exists.
# CONTEXT:  COPY actor, line 1
# psql:Data/pagila-data.sql:341: ERROR:  duplicate key value violates unique constraint "country_pkey"
# DETAIL:  Key (country_id)=(1) already exists.
# CONTEXT:  COPY country, line 1
# psql:Data/pagila-data.sql:949: ERROR:  duplicate key value violates unique constraint "city_pkey"
# DETAIL:  Key (city_id)=(1) already exists.
# CONTEXT:  COPY city, line 1
# psql:Data/pagila-data.sql:1560: ERROR:  duplicate key value violates unique constraint "address_pkey"
# DETAIL:  Key (address_id)=(1) already exists.
# CONTEXT:  COPY address, line 1
# psql:Data/pagila-data.sql:1584: ERROR:  duplicate key value violates unique constraint "category_pkey"
# DETAIL:  Key (category_id)=(1) already exists.
# CONTEXT:  COPY category, line 1
# psql:Data/pagila-data.sql:1594: ERROR:  duplicate key value violates unique constraint "store_pkey"
# DETAIL:  Key (store_id)=(1) already exists.
# CONTEXT:  COPY store, line 1
# psql:Data/pagila-data.sql:2201: ERROR:  duplicate key value violates unique constraint "customer_pkey"
# DETAIL:  Key (customer_id)=(1) already exists.
# CONTEXT:  COPY customer, line 1
# psql:Data/pagila-data.sql:2215: ERROR:  duplicate key value violates unique constraint "language_pkey"
# DETAIL:  Key (language_id)=(1) already exists.
# CONTEXT:  COPY language, line 1
# psql:Data/pagila-data.sql:3223: ERROR:  duplicate key value violates unique constraint "film_pkey"
# DETAIL:  Key (film_id)=(1) already exists.
# CONTEXT:  COPY film, line 1: "1	ACADEMY DINOSAUR	A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The C..."
# psql:Data/pagila-data.sql:8693: ERROR:  duplicate key value violates unique constraint "film_actor_pkey"
# DETAIL:  Key (actor_id, film_id)=(1, 1) already exists.
# CONTEXT:  COPY film_actor, line 1
# psql:Data/pagila-data.sql:9701: ERROR:  duplicate key value violates unique constraint "film_category_pkey"
# DETAIL:  Key (film_id, category_id)=(1, 6) already exists.
# CONTEXT:  COPY film_category, line 1
# psql:Data/pagila-data.sql:14290: ERROR:  duplicate key value violates unique constraint "inventory_pkey"
# DETAIL:  Key (inventory_id)=(1) already exists.
# CONTEXT:  COPY inventory, line 1
# psql:Data/pagila-data.sql:14300: ERROR:  duplicate key value violates unique constraint "staff_pkey"
# DETAIL:  Key (staff_id)=(1) already exists.
# CONTEXT:  COPY staff, line 1
# psql:Data/pagila-data.sql:30352: ERROR:  duplicate key value violates unique constraint "rental_pkey"
# DETAIL:  Key (rental_id)=(2) already exists.
# CONTEXT:  COPY rental, line 1
#  setval
# --------
#     200
# (1 row)
#
#  setval
# --------
#     605
# (1 row)
#
#  setval
# --------
#      16
# (1 row)
#
#  setval
# --------
#     600
# (1 row)
#
#  setval
# --------
#     109
# (1 row)
#
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#    1000
# (1 row)
#
#  setval
# --------
#    4581
# (1 row)
#
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#       2
# (1 row)
#
#  setval
# --------
#       2
# (1 row)

# %% [markdown]
# ## 1.2 Connect to the newly created db

# %%
# %load_ext sql

# %%
DB_ENDPOINT = "127.0.0.1"
DB = 'pagila'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila

# %%
# %sql $conn_string
# Out:
# 'Connected: student@pagila'

# %% [markdown]
# # STEP 1.1: Create and populate the star schema

# %% [markdown]
# # STEP2 : Explore the  3NF Schema

# %% [markdown]
# <img src="./pagila-3nf.png" width="50%"/>

# %% [markdown]
# ## 2.1 How much? What data sizes are we looking at?

# %%
nStores = %sql select count(*) from store;
nFilms = %sql select count(*) from film;
nCustomers = %sql select count(*) from customer;
nRentals = %sql select count(*) from rental;
nPayment = %sql select count(*) from payment;
nStaff = %sql select count(*) from staff;
nCity = %sql select count(*) from city;
nCountry = %sql select count(*) from country;

print("nFilms\t\t=", nFilms[0][0])
print("nCustomers\t=", nCustomers[0][0])
print("nRentals\t=", nRentals[0][0])
print("nPayment\t=", nPayment[0][0])
print("nStaff\t\t=", nStaff[0][0])
print("nStores\t\t=", nStores[0][0])
print("nCities\t\t=", nCity[0][0])
print("nCountry\t\t=", nCountry[0][0])
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# nFilms		= 1000
# nCustomers	= 599
# nRentals	= 16044
# nPayment	= 32098
# nStaff		= 2
# nStores		= 2
# nCities		= 600
# nCountry		= 109

# %% [markdown]
# ## 2.2 When? What time period are we talking about?

# %%
# %%sql
# select min(payment_date) as start, max(payment_date) as end from payment;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# [(datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), datetime.datetime(2017, 5, 14, 13, 44, 29, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ## 2.3 Where? Where do events in this database occur?

# %%
# %%sql
# select district,  sum(city_id) as n
# from address
# group by district
# order by n desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Shandong', 3237),
#  ('England', 2974),
#  ('So Paulo', 2952),
#  ('West Bengali', 2623),
#  ('Buenos Aires', 2572),
#  ('Uttar Pradesh', 2462),
#  ('California', 2444),
#  ('Southern Tagalog', 1931),
#  ('Tamil Nadu', 1807),
#  ('Hubei', 1790)]

# %% [markdown]
# # STEP3: Perform some simple data analysis

# %% [markdown]
# ## 3.1 Insight 1:   Top Grossing Movies
# - Payments amounts are in table `payment`
# - Movies are in table `film`
# - They are not directly linked, `payment` refers to a `rental`, `rental` refers to an `inventory` item and `inventory` item refers to a `film`
# - `payment` &rarr; `rental` &rarr; `inventory` &rarr; `film`

# %% [markdown]
# ### 3.1.1 Films

# %%
# %%sql
# select film_id, title, release_year, rental_rate, rating  from film limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 'ACADEMY DINOSAUR', 2006, Decimal('0.99'), 'PG'),
#  (2, 'ACE GOLDFINGER', 2006, Decimal('4.99'), 'G'),
#  (3, 'ADAPTATION HOLES', 2006, Decimal('2.99'), 'NC-17'),
#  (4, 'AFFAIR PREJUDICE', 2006, Decimal('2.99'), 'G'),
#  (5, 'AFRICAN EGG', 2006, Decimal('2.99'), 'G')]

# %% [markdown]
# ### 3.1.2 Payments

# %%
# %%sql
# select * from payment limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(16050, 269, 2, 7, Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16051, 269, 1, 98, Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16052, 269, 2, 678, Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16053, 269, 2, 703, Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16054, 269, 1, 750, Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ### 3.1.3 Inventory

# %%
# %%sql
# select * from inventory limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (2, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (3, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (4, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (5, 1, 2, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ### 3.1.4 Get the movie of every payment

# %%
# %%sql
# SELECT f.title, p.amount, p.payment_date, p.customer_id
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [('SWARM GOLD', Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('PACKER MADIGAN', Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('SOMETHING DUCK', Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('DRACULA CRYSTAL', Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('CLOSER BANG', Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269)]

# %% [markdown]
# ### 3.1.5 sum movie rental revenue

# %%
# %%sql
# SELECT f.title, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# GROUP BY title
# ORDER BY revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('TELEGRAPH VOYAGE', Decimal('463.46')),
#  ('WIFE TURN', Decimal('447.38')),
#  ('ZORRO ARK', Decimal('429.38')),
#  ('GOODFELLAS SALUTE', Decimal('419.38')),
#  ('SATURDAY LAMBS', Decimal('409.44')),
#  ('TITANS JERK', Decimal('403.42')),
#  ('TORQUE BOUND', Decimal('397.44')),
#  ('HARRY IDAHO', Decimal('391.40')),
#  ('INNOCENT USUAL', Decimal('383.48')),
#  ('HUSTLER PARTY', Decimal('381.56'))]

# %% [markdown]
# ## 3.2 Insight 2:   Top grossing cities
# - Payments amounts are in table `payment`
# - Cities are in table `cities`
# - `payment` &rarr; `customer` &rarr; `address` &rarr; `city`

# %% [markdown]
# ### 3.2.1 Get the city of each payment

# %%
# %%sql
# SELECT p.customer_id, p.rental_id, p.amount, ci.city
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [(130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (408, 3, Decimal('3.99'), 'Jaffna'),
#  (408, 3, Decimal('3.99'), 'Jaffna'),
#  (333, 4, Decimal('4.99'), 'Baku'),
#  (333, 4, Decimal('4.99'), 'Baku'),
#  (222, 5, Decimal('6.99'), 'Jaroslavl'),
#  (222, 5, Decimal('6.99'), 'Jaroslavl')]

# %% [markdown]
# ### 3.2.2 Top grossing cities

# %%
# %%sql
# SELECT ci.city ,  sum(p.amount) as revenue
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by ci.city
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Cape Coral', Decimal('443.10')),
#  ('Saint-Denis', Decimal('433.08')),
#  ('Aurora', Decimal('397.00')),
#  ('Molodetno', Decimal('391.16')),
#  ('Apeldoorn', Decimal('389.22')),
#  ('Santa Brbara dOeste', Decimal('389.22')),
#  ('Qomsheh', Decimal('373.24')),
#  ('London', Decimal('361.04')),
#  ('Ourense (Orense)', Decimal('355.20')),
#  ('Bijapur', Decimal('351.22'))]

# %% [markdown]
# ## 3.3 Insight 3 : Revenue of a movie by customer city and by month

# %% [markdown]
# ### 3.3.1 Total revenue by month

# %%
# %%sql
# SELECT sum(p.amount) as revenue, EXTRACT(month FROM p.payment_date) as month
# from payment p
# group by month
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(Decimal('57118.92'), 4.0),
#  (Decimal('47773.12'), 3.0),
#  (Decimal('19263.76'), 2.0),
#  (Decimal('9648.86'), 1.0),
#  (Decimal('1028.36'), 5.0)]

# %% [markdown]
# ### 3.3.2 Each movie by customer city and by month (data cube)

# %%
# %%sql
# SELECT f.title, p.amount, p.customer_id, ci.city, p.payment_date,EXTRACT(month FROM p.payment_date) as month
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('GRADUATE LORD', Decimal('3.99'), 408, 'Jaffna', datetime.datetime(2017, 1, 24, 21, 32, 5, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('GRADUATE LORD', Decimal('3.99'), 408, 'Jaffna', datetime.datetime(2017, 1, 24, 21, 32, 5, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('LOVE SUICIDES', Decimal('4.99'), 333, 'Baku', datetime.datetime(2017, 1, 24, 21, 33, 7, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('LOVE SUICIDES', Decimal('4.99'), 333, 'Baku', datetime.datetime(2017, 1, 24, 21, 33, 7, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('IDOLS SNATCHERS', Decimal('6.99'), 222, 'Jaroslavl', datetime.datetime(2017, 1, 24, 21, 33, 47, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('IDOLS SNATCHERS', Decimal('6.99'), 222, 'Jaroslavl', datetime.datetime(2017, 1, 24, 21, 33, 47, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0)]

# %% [markdown]
# ### 3.3.3 Sum of revenue of each movie by customer city and by month

# %%
# %%sql
# SELECT f.title, ci.city,EXTRACT(month FROM p.payment_date) as month, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by (f.title, ci.city, month)
# order by month, revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('SHOW LORD', 'Mannheim', 1.0, Decimal('23.98')),
#  ('KISSING DOLLS', 'Toulon', 1.0, Decimal('21.98')),
#  ('CASUALTIES ENCINO', 'Warren', 1.0, Decimal('21.98')),
#  ('TELEGRAPH VOYAGE', 'Naala-Porto', 1.0, Decimal('21.98')),
#  ('AMERICAN CIRCUS', 'Callao', 1.0, Decimal('21.98')),
#  ('CALIFORNIA BIRDS', 'Plock', 1.0, Decimal('19.98')),
#  ('AUTUMN CROW', 'Ashgabat', 1.0, Decimal('19.98')),
#  ('DAY UNFAITHFUL', 'Baybay', 1.0, Decimal('19.98')),
#  ('DARKO DORADO', 'Bhilwara', 1.0, Decimal('19.98')),
#  ('HEAD STRANGER', 'Xiangtan', 1.0, Decimal('19.98'))]

# %% [markdown]
# # STEP 4 : Creating Facts & Dimensions

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %%
# %%sql
# CREATE TABLE dimDate
# (
#   date_key integer NOT NULL PRIMARY KEY,
#   date date NOT NULL,
#   year smallint NOT NULL,
#   quarter smallint NOT NULL,
#   month smallint NOT NULL,
#   day smallint NOT NULL,
#   week smallint NOT NULL,
#   is_weekend boolean
# );
#
# CREATE TABLE dimCustomer
# (
#   customer_key SERIAL PRIMARY KEY,
#   customer_id  smallint NOT NULL,
#   first_name   varchar(45) NOT NULL,
#   last_name    varchar(45) NOT NULL,
#   email        varchar(50),
#   address      varchar(50) NOT NULL,
#   address2     varchar(50),
#   district     varchar(20) NOT NULL,
#   city         varchar(50) NOT NULL,
#   country      varchar(50) NOT NULL,
#   postal_code  varchar(10),
#   phone        varchar(20) NOT NULL,
#   active       smallint NOT NULL,
#   create_date  timestamp NOT NULL,
#   start_date   date NOT NULL,
#   end_date     date NOT NULL
# );
#
# CREATE TABLE dimMovie
# (
#   movie_key          SERIAL PRIMARY KEY,
#   film_id            smallint NOT NULL,
#   title              varchar(255) NOT NULL,
#   description        text,
#   release_year       year,
#   language           varchar(20) NOT NULL,
#   original_language  varchar(20),
#   rental_duration    smallint NOT NULL,
#   length             smallint NOT NULL,
#   rating             varchar(5) NOT NULL,
#   special_features   varchar(60) NOT NULL
# );
# CREATE TABLE dimStore
# (
#   store_key           SERIAL PRIMARY KEY,
#   store_id            smallint NOT NULL,
#   address             varchar(50) NOT NULL,
#   address2            varchar(50),
#   district            varchar(20) NOT NULL,
#   city                varchar(50) NOT NULL,
#   country             varchar(50) NOT NULL,
#   postal_code         varchar(10),
#   manager_first_name  varchar(45) NOT NULL,
#   manager_last_name   varchar(45) NOT NULL,
#   start_date          date NOT NULL,
#   end_date            date NOT NULL
# );
# CREATE TABLE factSales
# (
#   sales_key        SERIAL PRIMARY KEY,
#   date_key         INT NOT NULL REFERENCES dimDate(date_key),
#   customer_key     INT NOT NULL REFERENCES dimCustomer(customer_key),
#   movie_key        INT NOT NULL REFERENCES dimMovie(movie_key),
#   store_key        INT NOT NULL REFERENCES dimStore(store_key),
#   sales_amount     decimal(5,2) NOT NULL
# );
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# (psycopg2.ProgrammingError) relation "dimdate" already exists
#  [SQL: 'CREATE TABLE dimDate\n(\n  date_key integer NOT NULL PRIMARY KEY,\n  date date NOT NULL,\n  year smallint NOT NULL,\n  quarter smallint NOT NULL,\n  month smallint NOT NULL,\n  day smallint NOT NULL,\n  week smallint NOT NULL,\n  is_weekend boolean\n);']

# %% [markdown]
# # STEP 5: ETL the data from 3NF tables to Facts & Dimension Tables

# %%
# %%sql
# INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)
# SELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,
#        date(payment_date)                                           AS date,
#        EXTRACT(year FROM payment_date)                              AS year,
#        EXTRACT(quarter FROM payment_date)                           AS quarter,
#        EXTRACT(month FROM payment_date)                             AS month,
#        EXTRACT(day FROM payment_date)                               AS day,
#        EXTRACT(week FROM payment_date)                              AS week,
#        CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend
# FROM payment;
#
#
# INSERT INTO dimCustomer (customer_key, customer_id, first_name, last_name, email, address, address2, district, city, country, postal_code, phone, active, create_date, start_date, end_date)
# SELECT c.customer_id AS customer_key,
#        c.customer_id,
#        c.first_name,
#        c.last_name,
#        c.email,
#        a.address,
#        a.address2,
#        a.district,
#        ci.city,
#        co.country,
#        a.postal_code,
#        a.phone,
#        c.active,
#        c.create_date,
#        now()         AS start_date,
#        now()         AS end_date
# FROM customer c
# JOIN address a  ON (c.address_id = a.address_id)
# JOIN city ci    ON (a.city_id = ci.city_id)
# JOIN country co ON (ci.country_id = co.country_id);
#
# INSERT INTO dimMovie (movie_key, film_id, title, description, release_year, language, original_language, rental_duration, length, rating, special_features)
# SELECT f.film_id      AS movie_key,
#        f.film_id,
#        f.title,
#        f.description,
#        f.release_year,
#        l.name         AS language,
#        orig_lang.name AS original_language,
#        f.rental_duration,
#        f.length,
#        f.rating,
#        f.special_features
# FROM film f
# JOIN language l              ON (f.language_id=l.language_id)
# LEFT JOIN language orig_lang ON (f.original_language_id = orig_lang.language_id);
#
# INSERT INTO dimStore (store_key, store_id, address, address2, district, city, country, postal_code, manager_first_name, manager_last_name, start_date, end_date)
# SELECT s.store_id    AS store_key,
#        s.store_id,
#        a.address,
#        a.address2,
#        a.district,
#        c.city,
#        co.country,
#        a.postal_code,
#        st.first_name AS manager_first_name,
#        st.last_name  AS manager_last_name,
#        now()         AS start_date,
#        now()         AS end_date
# FROM store s
# JOIN staff st   ON (s.manager_staff_id = st.staff_id)
# JOIN address a  ON (s.address_id = a.address_id)
# JOIN city c     ON (a.city_id = c.city_id)
# JOIN country co ON (c.country_id = co.country_id);
#
# INSERT INTO factSales (date_key, customer_key, movie_key, store_key, sales_amount)
# SELECT TO_CHAR(p.payment_date :: DATE, 'yyyyMMDD')::integer AS date_key ,
#        p.customer_id                                        AS customer_key,
#        i.film_id                                            AS movie_key,
#        i.store_id                                           AS store_key,
#        p.amount                                             AS sales_amount
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id );
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# IntegrityError: duplicate key value violates unique constraint "dimdate_pkey"
# DETAIL:  Key (date_key)=(20170407) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-19-f4af0de3925d> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)\nSELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,\n       date(payment_date)                                           AS date,\n       EXTRACT(year FROM payment_date)                              AS year,\n       EXTRACT(quarter FROM payment_date)                           AS quarter,\n       EXTRACT(month FROM payment_date)                             AS month,\n       EXTRACT(day FROM payment_date)                               AS day,\n       EXTRACT(week FROM payment_date)                              AS week,\n       CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend\nFROM payment;\n\n\nINSERT INTO dimCustomer (customer_key, customer_id, first_name, last_name, email, address, address2, district, city, country, postal_code, phone, active, create_date, start_date, end_date)\nSELECT c.customer_id AS customer_key,\n       c.customer_id,\n       c.first_name,\n       c.last_name,\n       c.email,\n       a.address,\n       a.address2,\n       a.district,\n       ci.city,\n       co.country,\n       a.postal_code,\n       a.phone,\n       c.active,\n       c.create_date,\n       now()         AS start_date,\n       now()         AS end_date\nFROM customer c\nJOIN address a  ON (c.address_id = a.address_id)\nJOIN city ci    ON (a.city_id = ci.city_id)\nJOIN country co ON (ci.country_id = co.country_id);\n\nINSERT INTO dimMovie (movie_key, film_id, title, description, release_year, language, original_language, rental_duration, length, rating, special_features)\nSELECT f.film_id      AS movie_key,\n       f.film_id,\n       f.title,\n       f.description,\n       f.release_year,\n       l.name         AS language,\n       orig_lang.name AS original_language,\n       f.rental_duration,\n       f.length,\n       f.rating,\n       f.special_features\nFROM film f\nJOIN language l              ON (f.language_id=l.language_id)\nLEFT JOIN language orig_lang ON (f.original_language_id = orig_lang.language_id);\n\nINSERT INTO dimStore (store_key, store_id, address, address2, district, city, country, postal_code, manager_first_name, manager_last_name, start_date, end_date)\nSELECT s.store_id    AS store_key,\n       s.store_id,\n       a.address,\n       a.address2,\n       a.district,\n       c.city,\n       co.country,\n       a.postal_code,\n       st.first_name AS manager_first_name,\n       st.last_name  AS manager_last_name,\n       now()         AS start_date,\n       now()         AS end_date\nFROM store s\nJOIN staff st   ON (s.manager_staff_id = st.staff_id)\nJOIN address a  ON (s.address_id = a.address_id)\nJOIN city c     ON (a.city_id = c.city_id)\nJOIN country co ON (c.country_id = co.country_id);\n\nINSERT INTO factSales (date_key, customer_key, movie_key, store_key, sales_amount)\nSELECT TO_CHAR(p.payment_date :: DATE, 'yyyyMMDD')::integer AS date_key ,\n       p.customer_id                                        AS customer_key,\n       i.film_id                                            AS movie_key,\n       i.store_id                                           AS store_key,\n       p.amount                                             AS sales_amount\nFROM payment p\nJOIN rental r    ON ( p.rental_id = r.rental_id )\nJOIN inventory i ON ( r.inventory_id = i.inventory_id );")
#
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2165             magic_arg_s = self.var_expand(line, stack_depth)
#    2166             with self.builtin_trap:
# -> 2167                 result = fn(magic_arg_s, cell)
#    2168             return result
#    2169
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# /opt/conda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-125> in execute(self, line, cell, local_ns)
#
# /opt/conda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/conda/lib/python3.6/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /opt/conda/lib/python3.6/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
# --> 340                 result = conn.session.execute(txt, user_namespace)
#     341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     943             raise exc.ObjectNotExecutableError(object)
#     944         else:
# --> 945             return meth(self, multiparams, params)
#     946
#     947     def _execute_function(self, func, multiparams, params):
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     261     def _execute_on_connection(self, connection, multiparams, params):
#     262         if self.supports_execution:
# --> 263             return connection._execute_clauseelement(self, multiparams, params)
#     264         else:
#     265             raise exc.ObjectNotExecutableError(self)
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1051             compiled_sql,
#    1052             distilled_params,
# -> 1053             compiled_sql, distilled_params
#    1054         )
#    1055         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1187                 parameters,
#    1188                 cursor,
# -> 1189                 context)
#    1190
#    1191         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1400                 util.raise_from_cause(
#    1401                     sqlalchemy_exception,
# -> 1402                     exc_info
#    1403                 )
#    1404             else:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1180                         statement,
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#    1184             self._handle_dbapi_exception(
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     468
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#     472     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) duplicate key value violates unique constraint "dimdate_pkey"
# DETAIL:  Key (date_key)=(20170407) already exists.
#  [SQL: "INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)\nSELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,\n       date(payment_date)                                           AS date,\n       EXTRACT(year FROM payment_date)                              AS year,\n       EXTRACT(quarter FROM payment_date)                           AS quarter,\n       EXTRACT(month FROM payment_date)                             AS month,\n       EXTRACT(day FROM payment_date)                               AS day,\n       EXTRACT(week FROM payment_date)                              AS week,\n       CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend\nFROM payment;"]

# %% [markdown]
# # STEP 6: Repeat the computation from the facts & dimension table

# %% [markdown]
# ## 6.1 Facts Table has all the needed dimensions, no need for deep joins

# %%
# %%time
# %%sql
SELECT movie_key, date_key, customer_key, sales_amount
FROM factSales 
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 0 rows affected.
# CPU times: user 1.99 ms, sys: 1 ms, total: 3 ms
# Wall time: 2.59 ms
# []

# %% [markdown]
# ## 6.2 Join fact table with dimensions to replace keys with attributes

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sales_amount
FROM factSales 
JOIN dimMovie on (dimMovie.movie_key = factSales.movie_key)
JOIN dimDate on (dimDate.date_key = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 0 rows affected.
# CPU times: user 2.82 ms, sys: 662 µs, total: 3.48 ms
# Wall time: 3.12 ms
# []

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sum(sales_amount) as revenue
FROM factSales 
JOIN dimMovie    on (dimMovie.movie_key      = factSales.movie_key)
JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
group by (dimMovie.title, dimDate.month, dimCustomer.city)
order by dimMovie.title, dimDate.month, dimCustomer.city, revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 0 rows affected.
# CPU times: user 3.23 ms, sys: 1.07 ms, total: 4.3 ms
# Wall time: 4.63 ms
# []

# %%
# %%time
# %%sql
SELECT f.title, EXTRACT(month FROM p.payment_date) as month, ci.city, sum(p.amount) as revenue
FROM payment p
JOIN rental r    ON ( p.rental_id = r.rental_id )
JOIN inventory i ON ( r.inventory_id = i.inventory_id )
JOIN film f ON ( i.film_id = f.film_id)
JOIN customer c  ON ( p.customer_id = c.customer_id )
JOIN address a ON ( c.address_id = a.address_id )
JOIN city ci ON ( a.city_id = ci.city_id )
group by (f.title, month, ci.city)
order by f.title, month, ci.city, revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 15992 rows affected.
# CPU times: user 18.6 ms, sys: 8.19 ms, total: 26.8 ms
# Wall time: 135 ms
# [('ACADEMY DINOSAUR', 1.0, 'Celaya', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 1.0, 'Cianjur', Decimal('3.98')),
#  ('ACADEMY DINOSAUR', 2.0, 'San Lorenzo', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 2.0, 'Sullana', Decimal('3.98')),
#  ('ACADEMY DINOSAUR', 2.0, 'Udaipur', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Almirante Brown', Decimal('3.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Goinia', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Kaliningrad', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Kurashiki', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Livorno', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Nukualofa', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Rajkot', Decimal('7.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Sivas', Decimal('7.98')),
#  ('ACADEMY DINOSAUR', 3.0, 'Tabriz', Decimal('7.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'Charlotte Amalie', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'Hamilton', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'Jos Azueta', Decimal('3.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'Lipetsk', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'London', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'Pjatigorsk', Decimal('3.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'Sucre', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'Tel Aviv-Jaffa', Decimal('1.98')),
#  ('ACADEMY DINOSAUR', 4.0, 'Vila Velha', Decimal('1.98')),
#  ('ACE GOLDFINGER', 3.0, 'Binzhou', Decimal('17.98')),
#  ('ACE GOLDFINGER', 3.0, 'Kumbakonam', Decimal('9.98')),
#  ('ACE GOLDFINGER', 3.0, 'Pereira', Decimal('17.98')),
#  ('ACE GOLDFINGER', 3.0, 'Touliu', Decimal('19.98')),
#  ('ACE GOLDFINGER', 4.0, 'Simferopol', Decimal('19.98')),
#  ('ACE GOLDFINGER', 4.0, 'Soshanguve', Decimal('9.98')),
#  ('ACE GOLDFINGER', 5.0, 'Balikesir', Decimal('9.98')),
#  ('ADAPTATION HOLES', 1.0, 'Shikarpur', Decimal('5.98')),
#  ('ADAPTATION HOLES', 2.0, 'Jelets', Decimal('5.98')),
#  ('ADAPTATION HOLES', 3.0, 'al-Qatif', Decimal('5.98')),
#  ('ADAPTATION HOLES', 3.0, 'Cayenne', Decimal('5.98')),
#  ('ADAPTATION HOLES', 3.0, 'Coacalco de Berriozbal', Decimal('5.98')),
#  ('ADAPTATION HOLES', 3.0, 'Salinas', Decimal('5.98')),
#  ('ADAPTATION HOLES', 3.0, 'Santa Brbara dOeste', Decimal('5.98')),
#  ('ADAPTATION HOLES', 3.0, 'Sasebo', Decimal('9.98')),
#  ('ADAPTATION HOLES', 4.0, 'Jodhpur', Decimal('5.98')),
#  ('ADAPTATION HOLES', 4.0, 'Miraj', Decimal('5.98')),
#  ('ADAPTATION HOLES', 4.0, 'Ogbomosho', Decimal('5.98')),
#  ('ADAPTATION HOLES', 4.0, 'Urawa', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 1.0, 'Hidalgo', Decimal('7.98')),
#  ('AFFAIR PREJUDICE', 1.0, 'Tuguegarao', Decimal('7.98')),
#  ('AFFAIR PREJUDICE', 2.0, 'Changzhou', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 2.0, 'Crdoba', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 3.0, 'Aparecida de Goinia', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 3.0, 'Atinsk', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 3.0, 'Avellaneda', Decimal('13.98')),
#  ('AFFAIR PREJUDICE', 3.0, 'Caracas', Decimal('13.98')),
#  ('AFFAIR PREJUDICE', 3.0, 'Laiwu', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 3.0, 'Rancagua', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Chiayi', Decimal('9.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Ciomas', Decimal('11.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Lublin', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Malm', Decimal('11.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Palghat (Palakkad)', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Qomsheh', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Saint-Denis', Decimal('7.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'San Felipe de Puerto Plata', Decimal('9.98')),
#  ('AFFAIR PREJUDICE', 4.0, 's-Hertogenbosch', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Sirjan', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Sokoto', Decimal('9.98')),
#  ('AFFAIR PREJUDICE', 4.0, 'Tiefa', Decimal('5.98')),
#  ('AFFAIR PREJUDICE', 5.0, 'Caracas', Decimal('5.98')),
#  ('AFRICAN EGG', 1.0, 'Ivanovo', Decimal('7.98')),
#  ('AFRICAN EGG', 2.0, 'Okayama', Decimal('7.98')),
#  ('AFRICAN EGG', 2.0, 'Richmond Hill', Decimal('9.98')),
#  ('AFRICAN EGG', 3.0, 'Rampur', Decimal('7.98')),
#  ('AFRICAN EGG', 3.0, 'Smolensk', Decimal('9.98')),
#  ('AFRICAN EGG', 3.0, 'Tokat', Decimal('5.98')),
#  ('AFRICAN EGG', 4.0, 'Jedda', Decimal('9.98')),
#  ('AFRICAN EGG', 4.0, 'Jhansi', Decimal('5.98')),
#  ('AFRICAN EGG', 4.0, 'Kitwe', Decimal('9.98')),
#  ('AFRICAN EGG', 4.0, 'Salzburg', Decimal('11.98')),
#  ('AFRICAN EGG', 4.0, 'York', Decimal('9.98')),
#  ('AFRICAN EGG', 5.0, 'al-Manama', Decimal('5.98')),
#  ('AGENT TRUMAN', 1.0, 'Coatzacoalcos', Decimal('17.98')),
#  ('AGENT TRUMAN', 1.0, 'Izumisano', Decimal('11.98')),
#  ('AGENT TRUMAN', 2.0, 'Antofagasta', Decimal('7.98')),
#  ('AGENT TRUMAN', 2.0, 'Moscow', Decimal('17.98')),
#  ('AGENT TRUMAN', 2.0, 'Taizz', Decimal('13.98')),
#  ('AGENT TRUMAN', 3.0, 'Bhilwara', Decimal('17.98')),
#  ('AGENT TRUMAN', 3.0, 'Chisinau', Decimal('9.98')),
#  ('AGENT TRUMAN', 3.0, 'Citrus Heights', Decimal('13.98')),
#  ('AGENT TRUMAN', 3.0, 'Emeishan', Decimal('7.98')),
#  ('AGENT TRUMAN', 3.0, 'Luzinia', Decimal('7.98')),
#  ('AGENT TRUMAN', 3.0, 'Mogiljov', Decimal('13.98')),
#  ('AGENT TRUMAN', 3.0, 'Omdurman', Decimal('15.98')),
#  ('AGENT TRUMAN', 3.0, 'Sunnyvale', Decimal('9.98')),
#  ('AGENT TRUMAN', 3.0, 'Usak', Decimal('15.98')),
#  ('AGENT TRUMAN', 4.0, 'Aurora', Decimal('9.98')),
#  ('AGENT TRUMAN', 4.0, 'Huixquilucan', Decimal('9.98')),
#  ('AGENT TRUMAN', 4.0, 'Matsue', Decimal('11.98')),
#  ('AGENT TRUMAN', 4.0, 'Nantou', Decimal('5.98')),
#  ('AGENT TRUMAN', 4.0, 'Pontianak', Decimal('15.98')),
#  ('AGENT TRUMAN', 4.0, 'Quilmes', Decimal('5.98')),
#  ('AGENT TRUMAN', 4.0, 'Tafuna', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 2.0, 'Cavite', Decimal('15.98')),
#  ('AIRPLANE SIERRA', 2.0, 'Lubumbashi', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 3.0, 'Ibirit', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 3.0, 'Iwakuni', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 3.0, 'Johannesburg', Decimal('15.98')),
#  ('AIRPLANE SIERRA', 3.0, 'Jurez', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 3.0, 'Mahajanga', Decimal('11.98')),
#  ('AIRPLANE SIERRA', 3.0, 's-Hertogenbosch', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 4.0, 'Bhusawal', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 4.0, 'Kuwana', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 4.0, 'Salamanca', Decimal('11.98')),
#  ('AIRPLANE SIERRA', 4.0, 'Sincelejo', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 4.0, 'Tsuyama', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 4.0, 'Yuncheng', Decimal('9.98')),
#  ('AIRPLANE SIERRA', 4.0, 'Zalantun', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 1.0, 'Okinawa', Decimal('11.98')),
#  ('AIRPORT POLLOCK', 1.0, 'Pemalang', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 1.0, 'Taguig', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 2.0, 'Molodetno', Decimal('11.98')),
#  ('AIRPORT POLLOCK', 2.0, 'Portoviejo', Decimal('13.98')),
#  ('AIRPORT POLLOCK', 2.0, 'Vaduz', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 3.0, 'Augusta-Richmond County', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 3.0, 'Lilongwe', Decimal('15.98')),
#  ('AIRPORT POLLOCK', 3.0, 'Lublin', Decimal('13.98')),
#  ('AIRPORT POLLOCK', 3.0, 'Peoria', Decimal('11.98')),
#  ('AIRPORT POLLOCK', 3.0, 'Yangor', Decimal('11.98')),
#  ('AIRPORT POLLOCK', 4.0, 'Bamenda', Decimal('11.98')),
#  ('AIRPORT POLLOCK', 4.0, 'Dhaka', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 4.0, 'Erlangen', Decimal('11.98')),
#  ('AIRPORT POLLOCK', 4.0, 'Fukuyama', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 4.0, 'Palghat (Palakkad)', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 4.0, 'Sanaa', Decimal('9.98')),
#  ('AIRPORT POLLOCK', 4.0, 'San Juan Bautista Tuxtepec', Decimal('9.98')),
#  ('ALABAMA DEVIL', 3.0, 'Greensboro', Decimal('11.98')),
#  ('ALABAMA DEVIL', 3.0, 'Halifax', Decimal('15.98')),
#  ('ALABAMA DEVIL', 3.0, 'Otsu', Decimal('17.98')),
#  ('ALABAMA DEVIL', 3.0, 'Sunnyvale', Decimal('5.98')),
#  ('ALABAMA DEVIL', 3.0, 'Zaoyang', Decimal('11.98')),
#  ('ALABAMA DEVIL', 4.0, 'Arlington', Decimal('17.98')),
#  ('ALABAMA DEVIL', 4.0, 'Asuncin', Decimal('11.98')),
#  ('ALABAMA DEVIL', 4.0, 'Changhwa', Decimal('9.98')),
#  ('ALABAMA DEVIL', 4.0, 'Eskisehir', Decimal('5.98')),
#  ('ALABAMA DEVIL', 4.0, 'Kanazawa', Decimal('9.98')),
#  ('ALABAMA DEVIL', 4.0, 'Mit Ghamr', Decimal('5.98')),
#  ('ALABAMA DEVIL', 4.0, 'Probolinggo', Decimal('17.98')),
#  ('ALADDIN CALENDAR', 2.0, 'Kaduna', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 2.0, 'Kisumu', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 2.0, 'La Plata', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 2.0, 'Olomouc', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Adoni', Decimal('13.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Balaiha', Decimal('13.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Coacalco de Berriozbal', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Deba Habe', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Dos Quebradas', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Halisahar', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Mwanza', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Ranchi', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Sogamoso', Decimal('15.98')),
#  ('ALADDIN CALENDAR', 3.0, 'Zalantun', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Effon-Alaiye', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Esfahan', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Gulbarga', Decimal('15.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Hodeida', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Izumisano', Decimal('15.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Monclova', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Okinawa', Decimal('9.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Stockport', Decimal('11.98')),
#  ('ALADDIN CALENDAR', 4.0, 'Valencia', Decimal('15.98')),
#  ('ALAMO VIDEOTAPE', 1.0, 'Arecibo', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 1.0, 'Yuzhou', Decimal('7.98')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Meixian', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Rio Claro', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Tarlac', Decimal('3.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Baicheng', Decimal('3.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Bat Yam', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Ife', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Jinchang', Decimal('3.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Myingyan', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Papeete', Decimal('3.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Pudukkottai', Decimal('7.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Stara Zagora', Decimal('3.98')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Tanauan', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Berhampore (Baharampur)', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Duisburg', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Emmen', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Grand Prairie', Decimal('3.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Idfu', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Lapu-Lapu', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Owo', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Pemalang', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Zeleznogorsk', Decimal('1.98')),
#  ('ALASKA PHANTOM', 1.0, 'Nezahualcyotl', Decimal('1.98')),
#  ('ALASKA PHANTOM', 1.0, 'Zhezqazghan', Decimal('5.98')),
#  ('ALASKA PHANTOM', 2.0, 'al-Qadarif', Decimal('1.98')),
#  ('ALASKA PHANTOM', 2.0, 'Braslia', Decimal('5.98')),
#  ('ALASKA PHANTOM', 2.0, 'Maring', Decimal('1.98')),
#  ('ALASKA PHANTOM', 2.0, 'Sterling Heights', Decimal('3.98')),
#  ('ALASKA PHANTOM', 2.0, 'Touliu', Decimal('1.98')),
#  ('ALASKA PHANTOM', 3.0, 'Dhule (Dhulia)', Decimal('5.98')),
#  ('ALASKA PHANTOM', 3.0, 'Laohekou', Decimal('3.98')),
#  ('ALASKA PHANTOM', 3.0, 'Nabereznyje Telny', Decimal('1.98')),
#  ('ALASKA PHANTOM', 3.0, 'Nantou', Decimal('1.98')),
#  ('ALASKA PHANTOM', 3.0, 'Peoria', Decimal('7.98')),
#  ('ALASKA PHANTOM', 3.0, 'Saint Louis', Decimal('1.98')),
#  ('ALASKA PHANTOM', 3.0, 'Szkesfehrvr', Decimal('3.98')),
#  ('ALASKA PHANTOM', 3.0, 'Zhezqazghan', Decimal('1.98')),
#  ('ALASKA PHANTOM', 4.0, 'al-Hawiya', Decimal('1.98')),
#  ('ALASKA PHANTOM', 4.0, 'Baicheng', Decimal('1.98')),
#  ('ALASKA PHANTOM', 4.0, 'Bhilwara', Decimal('7.98')),
#  ('ALASKA PHANTOM', 4.0, 'Dhule (Dhulia)', Decimal('1.98')),
#  ('ALASKA PHANTOM', 4.0, 'Lhokseumawe', Decimal('3.98')),
#  ('ALASKA PHANTOM', 4.0, 'Ljubertsy', Decimal('1.98')),
#  ('ALASKA PHANTOM', 4.0, 'Mandi Bahauddin', Decimal('1.98')),
#  ('ALASKA PHANTOM', 4.0, 'Niznekamsk', Decimal('5.98')),
#  ('ALASKA PHANTOM', 4.0, 'Omdurman', Decimal('1.98')),
#  ('ALASKA PHANTOM', 4.0, 'Tiefa', Decimal('1.98')),
#  ('ALASKA PHANTOM', 4.0, 'Xiangtan', Decimal('3.98')),
#  ('ALIEN CENTER', 1.0, 'Caracas', Decimal('5.98')),
#  ('ALIEN CENTER', 1.0, 'Escobar', Decimal('5.98')),
#  ('ALIEN CENTER', 2.0, 'Baiyin', Decimal('5.98')),
#  ('ALIEN CENTER', 2.0, 'Lengshuijiang', Decimal('5.98')),
#  ('ALIEN CENTER', 2.0, 'Rancagua', Decimal('9.98')),
#  ('ALIEN CENTER', 3.0, 'Bag', Decimal('5.98')),
#  ('ALIEN CENTER', 3.0, 'Hsichuh', Decimal('5.98')),
#  ('ALIEN CENTER', 3.0, 'Huejutla de Reyes', Decimal('5.98')),
#  ('ALIEN CENTER', 3.0, 'Kragujevac', Decimal('5.98')),
#  ('ALIEN CENTER', 3.0, 'Memphis', Decimal('13.98')),
#  ('ALIEN CENTER', 3.0, 'Nagareyama', Decimal('5.98')),
#  ('ALIEN CENTER', 3.0, 'San Felipe de Puerto Plata', Decimal('11.98')),
#  ('ALIEN CENTER', 3.0, 'Sanya', Decimal('9.98')),
#  ('ALIEN CENTER', 3.0, 'Songkhla', Decimal('5.98')),
#  ('ALIEN CENTER', 4.0, 'Cuman', Decimal('5.98')),
#  ('ALIEN CENTER', 4.0, 'El Fuerte', Decimal('9.98')),
#  ('ALIEN CENTER', 4.0, 'Emeishan', Decimal('13.98')),
#  ('ALIEN CENTER', 4.0, 'Juazeiro do Norte', Decimal('7.98')),
#  ('ALIEN CENTER', 4.0, 'Richmond Hill', Decimal('5.98')),
#  ('ALIEN CENTER', 4.0, 'Shahr-e Kord', Decimal('5.98')),
#  ('ALIEN CENTER', 4.0, 'Xiangfan', Decimal('13.98')),
#  ('ALIEN CENTER', 4.0, 'Zhezqazghan', Decimal('11.98')),
#  ('ALI FOREVER', 3.0, 'Esfahan', Decimal('11.98')),
#  ('ALI FOREVER', 3.0, 'Lubumbashi', Decimal('9.98')),
#  ('ALI FOREVER', 3.0, 'Ourense (Orense)', Decimal('19.98')),
#  ('ALI FOREVER', 3.0, 'Sharja', Decimal('9.98')),
#  ('ALI FOREVER', 4.0, 'Cuauhtmoc', Decimal('15.98')),
#  ('ALI FOREVER', 4.0, 'Jakarta', Decimal('9.98')),
#  ('ALI FOREVER', 4.0, 'Maikop', Decimal('11.98')),
#  ('ALI FOREVER', 4.0, 'Vaduz', Decimal('9.98')),
#  ('ALI FOREVER', 5.0, 'Huixquilucan', Decimal('9.98')),
#  ('ALLEY EVOLUTION', 1.0, 'Najafabad', Decimal('11.98')),
#  ('ALLEY EVOLUTION', 2.0, 'Lancaster', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 2.0, 'Mexicali', Decimal('13.98')),
#  ('ALLEY EVOLUTION', 3.0, 'Aden', Decimal('9.98')),
#  ('ALLEY EVOLUTION', 3.0, 'Jos Azueta', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 3.0, 'Kalisz', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 3.0, 'Ponce', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 3.0, 'Shahr-e Kord', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 3.0, 'Tuguegarao', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 4.0, 'Esfahan', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 4.0, 'NDjamna', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 4.0, 'Shikarpur', Decimal('5.98')),
#  ('ALLEY EVOLUTION', 4.0, 'Tonghae', Decimal('9.98')),
#  ('ALLEY EVOLUTION', 4.0, 'Tsaotun', Decimal('5.98')),
#  ('ALONE TRIP', 1.0, 'Arak', Decimal('1.98')),
#  ('ALONE TRIP', 2.0, 'Almirante Brown', Decimal('1.98')),
#  ('ALONE TRIP', 2.0, 'Tuguegarao', Decimal('7.98')),
#  ('ALONE TRIP', 3.0, 'Kamjanets-Podilskyi', Decimal('7.98')),
#  ('ALONE TRIP', 3.0, 'Lungtan', Decimal('5.98')),
#  ('ALONE TRIP', 3.0, 'NDjamna', Decimal('1.98')),
#  ('ALONE TRIP', 3.0, 'Sincelejo', Decimal('5.98')),
#  ('ALONE TRIP', 3.0, 'Sousse', Decimal('9.98')),
#  ('ALONE TRIP', 3.0, 'Sterling Heights', Decimal('9.98')),
#  ('ALONE TRIP', 3.0, 'Tarsus', Decimal('5.98')),
#  ('ALONE TRIP', 3.0, 'Vinh', Decimal('3.98')),
#  ('ALONE TRIP', 4.0, 'Arecibo', Decimal('3.98')),
#  ('ALONE TRIP', 4.0, 'Cabuyao', Decimal('3.98')),
#  ('ALONE TRIP', 4.0, 'Hami', Decimal('13.98')),
#  ('ALONE TRIP', 4.0, 'Huixquilucan', Decimal('9.98')),
#  ('ALONE TRIP', 4.0, 'Mwanza', Decimal('13.98')),
#  ('ALONE TRIP', 4.0, 'Syktyvkar', Decimal('13.98')),
#  ('ALONE TRIP', 5.0, 'Tanza', Decimal('1.98')),
#  ('ALTER VICTORY', 1.0, 'Ezhou', Decimal('1.98')),
#  ('ALTER VICTORY', 1.0, 'Vinh', Decimal('1.98')),
#  ('ALTER VICTORY', 2.0, 'Charlotte Amalie', Decimal('1.98')),
#  ('ALTER VICTORY', 2.0, 'Cianjur', Decimal('1.98')),
#  ('ALTER VICTORY', 2.0, 'Purnea (Purnia)', Decimal('1.98')),
#  ('ALTER VICTORY', 3.0, 'Alessandria', Decimal('1.98')),
#  ('ALTER VICTORY', 3.0, 'Bijapur', Decimal('1.98')),
#  ('ALTER VICTORY', 3.0, 'Kamyin', Decimal('1.98')),
#  ('ALTER VICTORY', 3.0, 'Korolev', Decimal('1.98')),
#  ('ALTER VICTORY', 3.0, 'Meixian', Decimal('1.98')),
#  ('ALTER VICTORY', 3.0, 'Tongliao', Decimal('3.98')),
#  ('ALTER VICTORY', 4.0, 'Addis Abeba', Decimal('3.98')),
#  ('ALTER VICTORY', 4.0, 'Avellaneda', Decimal('1.98')),
#  ('ALTER VICTORY', 4.0, 'Bandar Seri Begawan', Decimal('1.98')),
#  ('ALTER VICTORY', 4.0, 'Boksburg', Decimal('1.98')),
#  ('ALTER VICTORY', 4.0, 'Kitwe', Decimal('7.98')),
#  ('ALTER VICTORY', 4.0, 'Nantou', Decimal('1.98')),
#  ('ALTER VICTORY', 4.0, 'Shaoguan', Decimal('7.98')),
#  ('ALTER VICTORY', 4.0, 'Shimonoseki', Decimal('1.98')),
#  ('ALTER VICTORY', 4.0, 'Sirjan', Decimal('7.98')),
#  ('ALTER VICTORY', 4.0, 'Tiefa', Decimal('1.98')),
#  ('ALTER VICTORY', 4.0, 'Urawa', Decimal('1.98')),
#  ('AMADEUS HOLY', 1.0, 'La Plata', Decimal('1.98')),
#  ('AMADEUS HOLY', 2.0, 'Denizli', Decimal('1.98')),
#  ('AMADEUS HOLY', 2.0, 'Jakarta', Decimal('1.98')),
#  ('AMADEUS HOLY', 2.0, 'Kurashiki', Decimal('1.98')),
#  ('AMADEUS HOLY', 2.0, 'Myingyan', Decimal('1.98')),
#  ('AMADEUS HOLY', 3.0, 'Araatuba', Decimal('1.98')),
#  ('AMADEUS HOLY', 3.0, 'Citt del Vaticano', Decimal('3.98')),
#  ('AMADEUS HOLY', 3.0, 'Joliet', Decimal('7.98')),
#  ('AMADEUS HOLY', 3.0, 'Laredo', Decimal('1.98')),
#  ('AMADEUS HOLY', 3.0, 'Matamoros', Decimal('1.98')),
#  ('AMADEUS HOLY', 3.0, 'Shubra al-Khayma', Decimal('7.98')),
#  ('AMADEUS HOLY', 3.0, 'Vila Velha', Decimal('1.98')),
#  ('AMADEUS HOLY', 4.0, 'Arak', Decimal('1.98')),
#  ('AMADEUS HOLY', 4.0, 'Bilbays', Decimal('3.98')),
#  ('AMADEUS HOLY', 4.0, 'Hohhot', Decimal('3.98')),
#  ('AMADEUS HOLY', 4.0, 'Jining', Decimal('1.98')),
#  ('AMADEUS HOLY', 4.0, 'Nabereznyje Telny', Decimal('1.98')),
#  ('AMADEUS HOLY', 4.0, 'Pjatigorsk', Decimal('1.98')),
#  ('AMADEUS HOLY', 4.0, 'Poos de Caldas', Decimal('7.98')),
#  ('AMADEUS HOLY', 4.0, 'Warren', Decimal('3.98')),
#  ('AMADEUS HOLY', 5.0, 'London', Decimal('1.98')),
#  ('AMELIE HELLFIGHTERS', 2.0, 'Acua', Decimal('9.98')),
#  ('AMELIE HELLFIGHTERS', 2.0, 'Ipoh', Decimal('11.98')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Anpolis', Decimal('9.98')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Sterling Heights', Decimal('9.98')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Tonghae', Decimal('17.98')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Botshabelo', Decimal('11.98')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Funafuti', Decimal('19.98')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Madiun', Decimal('9.98')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Meixian', Decimal('13.98')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'So Bernardo do Campo', Decimal('19.98')),
#  ('AMERICAN CIRCUS', 1.0, 'Callao', Decimal('21.98')),
#  ('AMERICAN CIRCUS', 1.0, 'Juazeiro do Norte', Decimal('9.98')),
#  ('AMERICAN CIRCUS', 2.0, 'Dos Quebradas', Decimal('19.98')),
#  ('AMERICAN CIRCUS', 2.0, 'El Fuerte', Decimal('13.98')),
#  ('AMERICAN CIRCUS', 2.0, 'Oulu', Decimal('9.98')),
#  ('AMERICAN CIRCUS', 3.0, 'Bayugan', Decimal('9.98')),
#  ('AMERICAN CIRCUS', 3.0, 'Bergamo', Decimal('11.98')),
#  ('AMERICAN CIRCUS', 3.0, 'Bijapur', Decimal('21.98')),
#  ('AMERICAN CIRCUS', 3.0, 'Changhwa', Decimal('9.98')),
#  ('AMERICAN CIRCUS', 3.0, 'Imus', Decimal('9.98')),
#  ('AMERICAN CIRCUS', 3.0, 'Konotop', Decimal('21.98')),
#  ('AMERICAN CIRCUS', 3.0, 'Nagaon', Decimal('9.98')),
#  ('AMERICAN CIRCUS', 3.0, 'Oulu', Decimal('9.98')),
#  ('AMERICAN CIRCUS', 4.0, 'Benguela', Decimal('19.98')),
#  ('AMERICAN CIRCUS', 4.0, 'Bydgoszcz', Decimal('9.98')),
#  ('AMERICAN CIRCUS', 4.0, 'Cabuyao', Decimal('17.98')),
#  ('AMERICAN CIRCUS', 4.0, 'Halle/Saale', Decimal('17.98')),
#  ('AMERICAN CIRCUS', 4.0, 'Juazeiro do Norte', Decimal('19.98')),
#  ('AMERICAN CIRCUS', 4.0, 'Nador', Decimal('17.98')),
#  ('AMERICAN CIRCUS', 4.0, 'Saint-Denis', Decimal('21.98')),
#  ('AMERICAN CIRCUS', 4.0, 'Tiefa', Decimal('17.98')),
#  ('AMERICAN CIRCUS', 5.0, 'Lipetsk', Decimal('9.98')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Akron', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Mysore', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Shimonoseki', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Elista', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Garland', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Jastrzebie-Zdrj', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Kolpino', Decimal('7.98')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Miyakonojo', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 3.0, 's-Hertogenbosch', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Vijayawada', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Zanzibar', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Apeldoorn', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Arecibo', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Avellaneda', Decimal('9.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Cavite', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Effon-Alaiye', Decimal('11.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Nantou', Decimal('7.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Sasebo', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Usak', Decimal('5.98')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Xinxiang', Decimal('7.98')),
#  ('AMISTAD MIDSUMMER', 5.0, 'Imus', Decimal('5.98')),
#  ('ANACONDA CONFESSIONS', 1.0, 'Fengshan', Decimal('1.98')),
#  ('ANACONDA CONFESSIONS', 1.0, 'Tarsus', Decimal('3.98')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Athenai', Decimal('13.98')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Dallas', Decimal('1.98')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Kermanshah', Decimal('3.98')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Nanyang', Decimal('7.98')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Otsu', Decimal('11.98')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Botshabelo', Decimal('1.98')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Haldia', Decimal('1.98')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Roanoke', Decimal('11.98')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Shanwei', Decimal('5.98')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Uttarpara-Kotrung', Decimal('1.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Batman', Decimal('11.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Caracas', Decimal('3.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Charlotte Amalie', Decimal('1.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Jelets', Decimal('3.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Molodetno', Decimal('7.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Sambhal', Decimal('5.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'San Juan Bautista Tuxtepec', Decimal('5.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Tanza', Decimal('7.98')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Vitria de Santo Anto', Decimal('1.98')),
#  ('ANALYZE HOOSIERS', 2.0, 'Saint Louis', Decimal('9.98')),
#  ('ANALYZE HOOSIERS', 2.0, 'Xintai', Decimal('5.98')),
#  ('ANALYZE HOOSIERS', 2.0, 'Yuncheng', Decimal('5.98')),
#  ('ANALYZE HOOSIERS', 3.0, 'Bijapur', Decimal('7.98')),
#  ('ANALYZE HOOSIERS', 3.0, 'Ciudad del Este', Decimal('5.98')),
#  ('ANALYZE HOOSIERS', 3.0, 'Joliet', Decimal('5.98')),
#  ('ANALYZE HOOSIERS', 3.0, 'Tartu', Decimal('9.98')),
#  ('ANALYZE HOOSIERS', 4.0, 'Ambattur', Decimal('9.98')),
#  ('ANALYZE HOOSIERS', 4.0, 'Celaya', Decimal('7.98')),
#  ('ANALYZE HOOSIERS', 4.0, 'Citrus Heights', Decimal('9.98')),
#  ('ANALYZE HOOSIERS', 4.0, 'Kurashiki', Decimal('11.98')),
#  ('ANALYZE HOOSIERS', 4.0, 'Kuwana', Decimal('5.98')),
#  ('ANALYZE HOOSIERS', 4.0, 'Usak', Decimal('5.98')),
#  ('ANALYZE HOOSIERS', 4.0, 'Valparai', Decimal('7.98')),
#  ('ANGELS LIFE', 1.0, 'Adana', Decimal('13.98')),
#  ('ANGELS LIFE', 1.0, 'Salala', Decimal('17.98')),
#  ('ANGELS LIFE', 2.0, 'Arecibo', Decimal('7.98')),
#  ('ANGELS LIFE', 2.0, 'Kermanshah', Decimal('7.98')),
#  ('ANGELS LIFE', 2.0, 'Urawa', Decimal('5.98')),
#  ('ANGELS LIFE', 3.0, 'Fukuyama', Decimal('7.98')),
#  ('ANGELS LIFE', 3.0, 'Greensboro', Decimal('5.98')),
#  ('ANGELS LIFE', 3.0, 'Kakamigahara', Decimal('5.98')),
#  ('ANGELS LIFE', 3.0, 'Nagareyama', Decimal('11.98')),
#  ('ANGELS LIFE', 3.0, 'Salamanca', Decimal('17.98')),
#  ('ANGELS LIFE', 3.0, 'San Juan Bautista Tuxtepec', Decimal('13.98')),
#  ('ANGELS LIFE', 3.0, 'Teboksary', Decimal('13.98')),
#  ('ANGELS LIFE', 3.0, 'Wroclaw', Decimal('15.98')),
#  ('ANGELS LIFE', 4.0, 'Ambattur', Decimal('5.98')),
#  ('ANGELS LIFE', 4.0, 'Augusta-Richmond County', Decimal('5.98')),
#  ('ANGELS LIFE', 4.0, 'Carmen', Decimal('11.98')),
#  ('ANGELS LIFE', 4.0, 'Kakamigahara', Decimal('7.98')),
#  ('ANGELS LIFE', 4.0, 'Korolev', Decimal('15.98')),
#  ('ANGELS LIFE', 4.0, 'Olomouc', Decimal('5.98')),
#  ('ANGELS LIFE', 4.0, 'Rampur', Decimal('17.98')),
#  ('ANGELS LIFE', 4.0, 'Sharja', Decimal('13.98')),
#  ('ANGELS LIFE', 4.0, 'York', Decimal('5.98')),
#  ('ANNIE IDENTITY', 1.0, 'Jedda', Decimal('7.98')),
#  ('ANNIE IDENTITY', 1.0, 'Maring', Decimal('7.98')),
#  ('ANNIE IDENTITY', 1.0, 'Tel Aviv-Jaffa', Decimal('1.98')),
#  ('ANNIE IDENTITY', 2.0, 'Battambang', Decimal('5.98')),
#  ('ANNIE IDENTITY', 2.0, 'Ede', Decimal('11.98')),
#  ('ANNIE IDENTITY', 2.0, 'Goinia', Decimal('1.98')),
#  ('ANNIE IDENTITY', 2.0, 'Tama', Decimal('1.98')),
#  ('ANNIE IDENTITY', 3.0, 'Ashqelon', Decimal('9.98')),
#  ('ANNIE IDENTITY', 3.0, 'Czestochowa', Decimal('9.98')),
#  ('ANNIE IDENTITY', 3.0, 'Myingyan', Decimal('3.98')),
#  ('ANNIE IDENTITY', 3.0, 'Pangkal Pinang', Decimal('1.98')),
#  ('ANNIE IDENTITY', 3.0, 'Santa F', Decimal('5.98')),
#  ('ANNIE IDENTITY', 3.0, 'Shaoguan', Decimal('13.98')),
#  ('ANNIE IDENTITY', 3.0, 'Yuncheng', Decimal('1.98')),
#  ('ANNIE IDENTITY', 4.0, 'Cabuyao', Decimal('1.98')),
#  ('ANNIE IDENTITY', 4.0, 'Luzinia', Decimal('1.98')),
#  ('ANNIE IDENTITY', 4.0, 'Oyo', Decimal('1.98')),
#  ('ANNIE IDENTITY', 4.0, 'Szkesfehrvr', Decimal('1.98')),
#  ('ANNIE IDENTITY', 4.0, 'Vilnius', Decimal('3.98')),
#  ('ANNIE IDENTITY', 4.0, 'Zanzibar', Decimal('1.98')),
#  ('ANNIE IDENTITY', 4.0, 'Zaria', Decimal('11.98')),
#  ('ANNIE IDENTITY', 4.0, 'Zhoushan', Decimal('5.98')),
#  ('ANONYMOUS HUMAN', 2.0, 'Uruapan', Decimal('3.98')),
#  ('ANONYMOUS HUMAN', 2.0, 'Varanasi (Benares)', Decimal('1.98')),
#  ('ANONYMOUS HUMAN', 3.0, 'Basel', Decimal('1.98')),
#  ('ANONYMOUS HUMAN', 3.0, 'Ezhou', Decimal('5.98')),
#  ('ANONYMOUS HUMAN', 3.0, 'Kowloon and New Kowloon', Decimal('1.98')),
#  ('ANONYMOUS HUMAN', 3.0, 'La Romana', Decimal('1.98')),
#  ('ANONYMOUS HUMAN', 3.0, 'San Bernardino', Decimal('1.98')),
#  ('ANONYMOUS HUMAN', 3.0, 'Zhezqazghan', Decimal('3.98')),
#  ('ANONYMOUS HUMAN', 4.0, 'Dhaka', Decimal('1.98')),
#  ('ANONYMOUS HUMAN', 4.0, 'Iwakuni', Decimal('1.98')),
#  ('ANONYMOUS HUMAN', 4.0, 'Kamakura', Decimal('3.98')),
#  ('ANONYMOUS HUMAN', 4.0, 'Liepaja', Decimal('1.98')),
#  ('ANONYMOUS HUMAN', 4.0, 'Richmond Hill', Decimal('1.98')),
#  ('ANTHEM LUKE', 1.0, 'Lengshuijiang', Decimal('13.98')),
#  ('ANTHEM LUKE', 1.0, 'Pyongyang', Decimal('9.98')),
#  ('ANTHEM LUKE', 1.0, 'Uluberia', Decimal('9.98')),
#  ('ANTHEM LUKE', 2.0, 'Ashgabat', Decimal('9.98')),
#  ('ANTHEM LUKE', 2.0, 'Cuauhtmoc', Decimal('9.98')),
#  ('ANTHEM LUKE', 2.0, 'San Felipe del Progreso', Decimal('9.98')),
#  ('ANTHEM LUKE', 3.0, 'Acua', Decimal('9.98')),
#  ('ANTHEM LUKE', 3.0, 'Fukuyama', Decimal('9.98')),
#  ('ANTHEM LUKE', 3.0, 'Ozamis', Decimal('9.98')),
#  ('ANTHEM LUKE', 4.0, 'Boa Vista', Decimal('17.98')),
#  ('ANTHEM LUKE', 4.0, 'Changzhou', Decimal('9.98')),
#  ('ANTHEM LUKE', 4.0, 'Coacalco de Berriozbal', Decimal('9.98')),
#  ('ANTHEM LUKE', 4.0, 'Kirovo-Tepetsk', Decimal('9.98')),
#  ('ANTHEM LUKE', 4.0, 'Kuwana', Decimal('11.98')),
#  ('ANTHEM LUKE', 4.0, 'Lhokseumawe', Decimal('17.98')),
#  ('ANTITRUST TOMATOES', 1.0, 'Erlangen', Decimal('5.98')),
#  ('ANTITRUST TOMATOES', 1.0, 'Novoterkassk', Decimal('5.98')),
#  ('ANTITRUST TOMATOES', 2.0, 'Lapu-Lapu', Decimal('13.98')),
#  ('ANTITRUST TOMATOES', 2.0, 'Sharja', Decimal('7.98')),
#  ('ANTITRUST TOMATOES', 3.0, 'Malm', Decimal('5.98')),
#  ('ANTITRUST TOMATOES', 3.0, 'Pereira', Decimal('5.98')),
#  ('ANTITRUST TOMATOES', 4.0, 'Bhimavaram', Decimal('7.98')),
#  ('ANTITRUST TOMATOES', 4.0, 'Fuyu', Decimal('9.98')),
#  ('ANTITRUST TOMATOES', 4.0, 'Vijayawada', Decimal('5.98')),
#  ('ANTITRUST TOMATOES', 4.0, 'Ziguinchor', Decimal('5.98')),
#  ('ANYTHING SAVANNAH', 1.0, 'Halle/Saale', Decimal('5.98')),
#  ('ANYTHING SAVANNAH', 2.0, 'Araatuba', Decimal('9.98')),
#  ('ANYTHING SAVANNAH', 2.0, 'Mexicali', Decimal('13.98')),
#  ('ANYTHING SAVANNAH', 3.0, 'Cam Ranh', Decimal('7.98')),
#  ('ANYTHING SAVANNAH', 3.0, 'El Monte', Decimal('11.98')),
#  ('ANYTHING SAVANNAH', 3.0, 'Gandhinagar', Decimal('5.98')),
#  ('ANYTHING SAVANNAH', 3.0, 'Yangor', Decimal('15.98')),
#  ('ANYTHING SAVANNAH', 4.0, 'Banjul', Decimal('15.98')),
#  ('ANYTHING SAVANNAH', 4.0, 'Zaoyang', Decimal('5.98')),
#  ('APACHE DIVINE', 1.0, 'Cavite', Decimal('9.98')),
#  ('APACHE DIVINE', 1.0, 'Mukateve', Decimal('15.98')),
#  ('APACHE DIVINE', 1.0, 'So Leopoldo', Decimal('9.98')),
#  ('APACHE DIVINE', 2.0, 'Bamenda', Decimal('9.98')),
#  ('APACHE DIVINE', 2.0, 'Cam Ranh', Decimal('9.98')),
#  ('APACHE DIVINE', 2.0, 'Iwaki', Decimal('9.98')),
#  ('APACHE DIVINE', 2.0, 'Taizz', Decimal('9.98')),
#  ('APACHE DIVINE', 3.0, 'Balikesir', Decimal('13.98')),
#  ('APACHE DIVINE', 3.0, 'Boksburg', Decimal('15.98')),
#  ('APACHE DIVINE', 3.0, 'El Fuerte', Decimal('13.98')),
#  ('APACHE DIVINE', 3.0, 'Guadalajara', Decimal('9.98')),
#  ('APACHE DIVINE', 3.0, 'Kanazawa', Decimal('9.98')),
#  ('APACHE DIVINE', 3.0, 'Maikop', Decimal('11.98')),
#  ('APACHE DIVINE', 3.0, 'Moscow', Decimal('11.98')),
#  ('APACHE DIVINE', 3.0, 'Okinawa', Decimal('17.98')),
#  ('APACHE DIVINE', 3.0, 'Sorocaba', Decimal('9.98')),
#  ('APACHE DIVINE', 3.0, 'Urawa', Decimal('9.98')),
#  ('APACHE DIVINE', 3.0, 'Zanzibar', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'Bandar Seri Begawan', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'Carmen', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'Greensboro', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'Jaffna', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'Kimberley', Decimal('11.98')),
#  ('APACHE DIVINE', 4.0, 'Malm', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'Mit Ghamr', Decimal('13.98')),
#  ('APACHE DIVINE', 4.0, 'Oshawa', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'Pereira', Decimal('11.98')),
#  ('APACHE DIVINE', 4.0, 'Robamba', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'Taguig', Decimal('11.98')),
#  ('APACHE DIVINE', 4.0, 'Tiefa', Decimal('9.98')),
#  ('APACHE DIVINE', 4.0, 'York', Decimal('15.98')),
#  ('APOCALYPSE FLAMINGOS', 2.0, 'Kalisz', Decimal('11.98')),
#  ('APOCALYPSE FLAMINGOS', 3.0, 'Chandrapur', Decimal('9.98')),
#  ('APOCALYPSE FLAMINGOS', 3.0, 'Ikerre', Decimal('9.98')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Belm', Decimal('9.98')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Blumenau', Decimal('9.98')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Ruse', Decimal('9.98')),
#  ('ARABIA DOGMA', 1.0, 'Tartu', Decimal('1.98')),
#  ('ARABIA DOGMA', 2.0, 'Qalyub', Decimal('1.98')),
#  ('ARABIA DOGMA', 2.0, 'Toulouse', Decimal('1.98')),
#  ('ARABIA DOGMA', 3.0, 'Amroha', Decimal('1.98')),
#  ('ARABIA DOGMA', 3.0, 'La Plata', Decimal('7.98')),
#  ('ARABIA DOGMA', 3.0, 'London', Decimal('7.98')),
#  ('ARABIA DOGMA', 3.0, 'Lubumbashi', Decimal('1.98')),
#  ('ARABIA DOGMA', 3.0, 'Monclova', Decimal('7.98')),
#  ('ARABIA DOGMA', 3.0, 'Tokat', Decimal('3.98')),
#  ('ARABIA DOGMA', 4.0, 'Changzhou', Decimal('1.98')),
#  ('ARABIA DOGMA', 4.0, 'Lapu-Lapu', Decimal('1.98')),
#  ('ARABIA DOGMA', 4.0, 'Tuguegarao', Decimal('1.98')),
#  ('ARABIA DOGMA', 4.0, 'Usak', Decimal('1.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Arlington', Decimal('9.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Bhusawal', Decimal('5.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Mwene-Ditu', Decimal('11.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Tonghae', Decimal('9.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Czestochowa', Decimal('13.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Higashiosaka', Decimal('7.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Kimberley', Decimal('5.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Matsue', Decimal('7.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Ondo', Decimal('13.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Parbhani', Decimal('7.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Zalantun', Decimal('11.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Chapra', Decimal('13.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Dadu', Decimal('5.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Fuyu', Decimal('7.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Gaziantep', Decimal('15.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Goinia', Decimal('5.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Jamalpur', Decimal('9.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Kamakura', Decimal('5.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Myingyan', Decimal('7.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Rio Claro', Decimal('7.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Roanoke', Decimal('5.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Usak', Decimal('11.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Vicente Lpez', Decimal('15.98')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Zhezqazghan', Decimal('5.98')),
#  ('ARIZONA BANG', 2.0, 'guas Lindas de Gois', Decimal('5.98')),
#  ('ARIZONA BANG', 2.0, 'Jalib al-Shuyukh', Decimal('11.98')),
#  ('ARIZONA BANG', 2.0, 'Szkesfehrvr', Decimal('5.98')),
#  ('ARIZONA BANG', 3.0, 'Hamilton', Decimal('5.98')),
#  ('ARIZONA BANG', 3.0, 'Kowloon and New Kowloon', Decimal('15.98')),
#  ('ARIZONA BANG', 3.0, 'Molodetno', Decimal('9.98')),
#  ('ARIZONA BANG', 3.0, 'Nantou', Decimal('5.98')),
#  ('ARIZONA BANG', 3.0, 'Palghat (Palakkad)', Decimal('15.98')),
#  ('ARIZONA BANG', 3.0, 'Pontianak', Decimal('9.98')),
#  ('ARIZONA BANG', 3.0, 'Probolinggo', Decimal('5.98')),
#  ('ARIZONA BANG', 3.0, 'Rajkot', Decimal('15.98')),
#  ('ARIZONA BANG', 3.0, 'Salala', Decimal('5.98')),
#  ('ARIZONA BANG', 3.0, 'Shikarpur', Decimal('9.98')),
#  ('ARIZONA BANG', 3.0, 'Springs', Decimal('11.98')),
#  ('ARIZONA BANG', 3.0, 'Vijayawada', Decimal('13.98')),
#  ('ARIZONA BANG', 4.0, 'Battambang', Decimal('7.98')),
#  ('ARIZONA BANG', 4.0, 'Davao', Decimal('9.98')),
#  ('ARIZONA BANG', 4.0, 'Lancaster', Decimal('11.98')),
#  ('ARIZONA BANG', 4.0, 'Liepaja', Decimal('15.98')),
#  ('ARIZONA BANG', 4.0, 'Osmaniye', Decimal('5.98')),
#  ('ARIZONA BANG', 4.0, 'Saint-Denis', Decimal('5.98')),
#  ('ARMAGEDDON LOST', 1.0, 'Dallas', Decimal('7.98')),
#  ('ARMAGEDDON LOST', 2.0, 'Surakarta', Decimal('9.98')),
#  ('ARMAGEDDON LOST', 2.0, 'Tallahassee', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 3.0, 'Bhavnagar', Decimal('7.98')),
#  ('ARMAGEDDON LOST', 3.0, 'Dzerzinsk', Decimal('11.98')),
#  ('ARMAGEDDON LOST', 3.0, 'Hanoi', Decimal('3.98')),
#  ('ARMAGEDDON LOST', 3.0, 'Nanyang', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 3.0, 'NDjamna', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 3.0, 'Rio Claro', Decimal('3.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Ambattur', Decimal('5.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Bradford', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Cheju', Decimal('3.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Cianjur', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Hiroshima', Decimal('5.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Luzinia', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Nakhon Sawan', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Rae Bareli', Decimal('7.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Saint-Denis', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Szkesfehrvr', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 4.0, 'Uijongbu', Decimal('1.98')),
#  ('ARMAGEDDON LOST', 5.0, 'Trshavn', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 1.0, 'Lublin', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 1.0, 'Sunnyvale', Decimal('7.98')),
#  ('ARMY FLINTSTONES', 2.0, 'Kamarhati', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 2.0, 'Rae Bareli', Decimal('5.98')),
#  ('ARMY FLINTSTONES', 2.0, 'Sterling Heights', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 3.0, 'Boa Vista', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 3.0, 'Lengshuijiang', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 3.0, 'Po', Decimal('7.98')),
#  ('ARMY FLINTSTONES', 3.0, 'Yamuna Nagar', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 3.0, 'Yuzhou', Decimal('9.98')),
#  ('ARMY FLINTSTONES', 4.0, 'Aden', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 4.0, 'Cavite', Decimal('1.98')),
#  ('ARMY FLINTSTONES', 4.0, 'Jodhpur', Decimal('5.98')),
#  ('ARMY FLINTSTONES', 4.0, 'Kurashiki', Decimal('7.98')),
#  ('ARMY FLINTSTONES', 4.0, 'Pune', Decimal('7.98')),
#  ('ARMY FLINTSTONES', 4.0, 'Skikda', Decimal('13.98')),
#  ('ARTIST COLDBLOODED', 1.0, 'Ogbomosho', Decimal('13.98')),
#  ('ARTIST COLDBLOODED', 1.0, 'Rajkot', Decimal('5.98')),
#  ('ARTIST COLDBLOODED', 2.0, 'Hamilton', Decimal('5.98')),
#  ('ARTIST COLDBLOODED', 2.0, 'Myingyan', Decimal('5.98')),
#  ('ARTIST COLDBLOODED', 2.0, 'Valencia', Decimal('7.98')),
#  ('ARTIST COLDBLOODED', 3.0, 'Funafuti', Decimal('5.98')),
#  ('ARTIST COLDBLOODED', 3.0, 'Jastrzebie-Zdrj', Decimal('7.98')),
#  ('ARTIST COLDBLOODED', 3.0, 'Mosul', Decimal('5.98')),
#  ('ARTIST COLDBLOODED', 3.0, 'Tafuna', Decimal('5.98')),
#  ('ARTIST COLDBLOODED', 4.0, 'Ashdod', Decimal('13.98')),
#  ('ARTIST COLDBLOODED', 4.0, 'Bijapur', Decimal('11.98')),
#  ('ARTIST COLDBLOODED', 4.0, 'Duisburg', Decimal('5.98')),
#  ('ARTIST COLDBLOODED', 4.0, 'Juazeiro do Norte', Decimal('13.98')),
#  ('ARTIST COLDBLOODED', 4.0, 'Lubumbashi', Decimal('11.98')),
#  ('ARTIST COLDBLOODED', 4.0, 'Nha Trang', Decimal('9.98')),
#  ('ARTIST COLDBLOODED', 4.0, 'Zaria', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 1.0, 's-Hertogenbosch', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 1.0, 'Sivas', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 2.0, 'Balurghat', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 2.0, 'Beni-Mellal', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 2.0, 'Fuzhou', Decimal('11.98')),
#  ('ATLANTIS CAUSE', 3.0, 'al-Manama', Decimal('11.98')),
#  ('ATLANTIS CAUSE', 3.0, 'Brockton', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 3.0, 'Caracas', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 3.0, 'Emmen', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 3.0, 'guas Lindas de Gois', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 3.0, 'Jodhpur', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 3.0, 'Sambhal', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 3.0, 'Sogamoso', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 3.0, 'Tabriz', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 3.0, 'Tanauan', Decimal('11.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Abu Dhabi', Decimal('7.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Ashgabat', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Deba Habe', Decimal('11.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Duisburg', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Jining', Decimal('7.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Klerksdorp', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Pontianak', Decimal('5.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Pudukkottai', Decimal('7.98')),
#  ('ATLANTIS CAUSE', 4.0, 'Xiangfan', Decimal('7.98')),
#  ('ATTACKS HATE', 2.0, 'Sasebo', Decimal('9.98')),
#  ('ATTACKS HATE', 2.0, 'Yangor', Decimal('15.98')),
#  ('ATTACKS HATE', 3.0, 'Aden', Decimal('15.98')),
#  ('ATTACKS HATE', 3.0, 'Antofagasta', Decimal('17.98')),
#  ('ATTACKS HATE', 3.0, 'Banjul', Decimal('17.98')),
#  ('ATTACKS HATE', 3.0, 'Ife', Decimal('9.98')),
#  ('ATTACKS HATE', 3.0, 'Munger (Monghyr)', Decimal('9.98')),
#  ('ATTACKS HATE', 3.0, 'Owo', Decimal('11.98')),
#  ('ATTACKS HATE', 4.0, 'Ashdod', Decimal('11.98')),
#  ('ATTACKS HATE', 4.0, 'Bern', Decimal('9.98')),
#  ('ATTACKS HATE', 4.0, 'Carmen', Decimal('9.98')),
#  ('ATTACKS HATE', 4.0, 'Ipoh', Decimal('9.98')),
#  ('ATTACKS HATE', 4.0, 'Matsue', Decimal('11.98')),
#  ('ATTACKS HATE', 4.0, 'Sumy', Decimal('17.98')),
#  ('ATTACKS HATE', 4.0, 'Tangail', Decimal('11.98')),
#  ('ATTACKS HATE', 4.0, 'Ueda', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 1.0, 'Sincelejo', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 2.0, 'Ezhou', Decimal('15.98')),
#  ('ATTRACTION NEWTON', 2.0, 'Lengshuijiang', Decimal('13.98')),
#  ('ATTRACTION NEWTON', 2.0, 'Nagaon', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 2.0, 'Portoviejo', Decimal('17.98')),
#  ('ATTRACTION NEWTON', 2.0, 'Tete', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Changzhou', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Jakarta', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Kimberley', Decimal('17.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Mit Ghamr', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Monywa', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Mukateve', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Patiala', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Salzburg', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Southend-on-Sea', Decimal('13.98')),
#  ('ATTRACTION NEWTON', 3.0, 'Zapopan', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 4.0, 'Akishima', Decimal('15.98')),
#  ('ATTRACTION NEWTON', 4.0, 'Amroha', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 4.0, 'Batna', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 4.0, 'Fontana', Decimal('11.98')),
#  ('ATTRACTION NEWTON', 4.0, 'Maikop', Decimal('9.98')),
#  ('ATTRACTION NEWTON', 4.0, 'Maracabo', Decimal('17.98')),
#  ('ATTRACTION NEWTON', 4.0, 'Tongliao', Decimal('11.98')),
#  ('ATTRACTION NEWTON', 4.0, 'Zeleznogorsk', Decimal('15.98')),
#  ('AUTUMN CROW', 1.0, 'Ashgabat', Decimal('19.98')),
#  ('AUTUMN CROW', 2.0, 'Iwakuni', Decimal('13.98')),
#  ('AUTUMN CROW', 2.0, 'Stockport', Decimal('21.98')),
#  ('AUTUMN CROW', 3.0, 'Basel', Decimal('19.98')),
#  ('AUTUMN CROW', 3.0, 'Blumenau', Decimal('19.98')),
#  ('AUTUMN CROW', 3.0, 'Touliu', Decimal('11.98')),
#  ('AUTUMN CROW', 4.0, 'Aparecida de Goinia', Decimal('9.98')),
#  ('AUTUMN CROW', 4.0, 'Dallas', Decimal('9.98')),
#  ('AUTUMN CROW', 4.0, 'Fontana', Decimal('19.98')),
#  ('AUTUMN CROW', 4.0, 'Sincelejo', Decimal('9.98')),
#  ('AUTUMN CROW', 4.0, 'Tanshui', Decimal('11.98')),
#  ('BABY HALL', 1.0, 'Novoterkassk', Decimal('9.98')),
#  ('BABY HALL', 2.0, 'Memphis', Decimal('11.98')),
#  ('BABY HALL', 3.0, 'Lilongwe', Decimal('9.98')),
#  ('BABY HALL', 3.0, 'Osmaniye', Decimal('9.98')),
#  ('BABY HALL', 3.0, 'San Juan Bautista Tuxtepec', Decimal('9.98')),
#  ('BABY HALL', 4.0, 'Ilorin', Decimal('13.98')),
#  ('BABY HALL', 4.0, 'Lincoln', Decimal('9.98')),
#  ('BABY HALL', 4.0, 'Surakarta', Decimal('15.98')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Kaliningrad', Decimal('11.98')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Kamyin', Decimal('9.98')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Maring', Decimal('13.98')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Bellevue', Decimal('19.98')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Cuauhtmoc', Decimal('19.98')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Jedda', Decimal('9.98')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Springs', Decimal('9.98')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Blumenau', Decimal('21.98')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Etawah', Decimal('19.98')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Kursk', Decimal('19.98')),
#  ('BACKLASH UNDEFEATED', 3.0, 'London', Decimal('19.98')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Elista', Decimal('17.98')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Escobar', Decimal('17.98')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Loja', Decimal('19.98')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Omdurman', Decimal('17.98')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Pontianak', Decimal('17.98')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Tarlac', Decimal('15.98')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Uijongbu', Decimal('11.98')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Uttarpara-Kotrung', Decimal('19.98')),
#  ('BADMAN DAWN', 2.0, 'Huixquilucan', Decimal('5.98')),
#  ('BADMAN DAWN', 2.0, 'Rizhao', Decimal('5.98')),
#  ('BADMAN DAWN', 2.0, 'Tanza', Decimal('11.98')),
#  ('BADMAN DAWN', 2.0, 'Tieli', Decimal('9.98')),
#  ('BADMAN DAWN', 3.0, 'Alvorada', Decimal('5.98')),
#  ('BADMAN DAWN', 3.0, 'Fukuyama', Decimal('5.98')),
#  ('BADMAN DAWN', 3.0, 'Hami', Decimal('11.98')),
#  ('BADMAN DAWN', 3.0, 'Najafabad', Decimal('5.98')),
#  ('BADMAN DAWN', 3.0, 'Simferopol', Decimal('7.98')),
#  ('BADMAN DAWN', 3.0, 'Soshanguve', Decimal('5.98')),
#  ('BADMAN DAWN', 4.0, 'Abha', Decimal('5.98')),
#  ('BADMAN DAWN', 4.0, 'Balikesir', Decimal('5.98')),
#  ('BADMAN DAWN', 4.0, 'Beira', Decimal('9.98')),
#  ('BADMAN DAWN', 4.0, 'Citt del Vaticano', Decimal('7.98')),
#  ('BADMAN DAWN', 4.0, 'Oyo', Decimal('5.98')),
#  ('BADMAN DAWN', 4.0, 'Ozamis', Decimal('5.98')),
#  ('BADMAN DAWN', 4.0, 'Pak Kret', Decimal('13.96')),
#  ('BADMAN DAWN', 4.0, 'Serpuhov', Decimal('5.98')),
#  ('BADMAN DAWN', 4.0, 'Siliguri (Shiliguri)', Decimal('5.98')),
#  ('BADMAN DAWN', 4.0, 'Zaoyang', Decimal('7.98')),
#  ('BAKED CLEOPATRA', 1.0, 'Okayama', Decimal('5.98')),
#  ('BAKED CLEOPATRA', 2.0, 'Tarsus', Decimal('5.98')),
#  ('BAKED CLEOPATRA', 3.0, 'Garden Grove', Decimal('11.98')),
#  ('BAKED CLEOPATRA', 3.0, 'Hiroshima', Decimal('7.98')),
#  ('BAKED CLEOPATRA', 3.0, 'Madiun', Decimal('5.98')),
#  ('BAKED CLEOPATRA', 3.0, 'Santa Rosa', Decimal('13.98')),
#  ('BAKED CLEOPATRA', 4.0, 'Acua', Decimal('9.98')),
#  ('BAKED CLEOPATRA', 4.0, 'Bergamo', Decimal('13.98')),
#  ('BAKED CLEOPATRA', 4.0, 'Gandhinagar', Decimal('5.98')),
#  ('BAKED CLEOPATRA', 4.0, 'Hodeida', Decimal('13.98')),
#  ('BAKED CLEOPATRA', 4.0, 'Ourense (Orense)', Decimal('13.98')),
#  ('BAKED CLEOPATRA', 4.0, 'Phnom Penh', Decimal('5.98')),
#  ('BAKED CLEOPATRA', 4.0, 'San Miguel de Tucumn', Decimal('5.98')),
#  ('BAKED CLEOPATRA', 4.0, 'Valencia', Decimal('15.98')),
#  ('BAKED CLEOPATRA', 4.0, 'Vila Velha', Decimal('15.98')),
#  ('BAKED CLEOPATRA', 5.0, 'Haiphong', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 1.0, 'Witten', Decimal('13.98')),
#  ('BALLOON HOMEWARD', 2.0, 'Botosani', Decimal('7.98')),
#  ('BALLOON HOMEWARD', 2.0, 'Datong', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 2.0, 'Pak Kret', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 2.0, 'Plock', Decimal('7.98')),
#  ('BALLOON HOMEWARD', 2.0, 'Vitria de Santo Anto', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Allende', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Araatuba', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Binzhou', Decimal('13.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Cianjur', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Fuyu', Decimal('7.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Livorno', Decimal('7.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Salzburg', Decimal('13.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Udaipur', Decimal('11.98')),
#  ('BALLOON HOMEWARD', 3.0, 'Zaoyang', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 4.0, 'Beira', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 4.0, 'Beni-Mellal', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 4.0, 'Bucuresti', Decimal('13.98')),
#  ('BALLOON HOMEWARD', 4.0, 'Junan', Decimal('9.98')),
#  ('BALLOON HOMEWARD', 4.0, 'Roanoke', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 4.0, 'Yantai', Decimal('7.98')),
#  ('BALLOON HOMEWARD', 4.0, 'Yerevan', Decimal('5.98')),
#  ('BALLOON HOMEWARD', 4.0, 'Yinchuan', Decimal('13.98')),
#  ('BALLROOM MOCKINGBIRD', 1.0, 'Valparai', Decimal('1.98')),
#  ('BALLROOM MOCKINGBIRD', 2.0, 'Compton', Decimal('1.98')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Cam Ranh', Decimal('1.98')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Omiya', Decimal('1.98')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Tychy', Decimal('3.98')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Effon-Alaiye', Decimal('1.98')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Malm', Decimal('5.98')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Tarsus', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 1.0, 'Shubra al-Khayma', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 1.0, 'Tonghae', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 2.0, 'Cabuyao', Decimal('3.98')),
#  ('BANGER PINOCCHIO', 2.0, 'Cavite', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 2.0, 'Munger (Monghyr)', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 2.0, 'Novoterkassk', Decimal('5.98')),
#  ('BANGER PINOCCHIO', 2.0, 'Siliguri (Shiliguri)', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 3.0, 'Abha', Decimal('3.98')),
#  ('BANGER PINOCCHIO', 3.0, 'Binzhou', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 3.0, 'Emeishan', Decimal('5.98')),
#  ('BANGER PINOCCHIO', 3.0, 'Kaduna', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 3.0, 'Ocumare del Tuy', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 3.0, 'Simferopol', Decimal('9.98')),
#  ('BANGER PINOCCHIO', 3.0, 'Tama', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 4.0, 'Almirante Brown', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 4.0, 'Bamenda', Decimal('5.98')),
#  ('BANGER PINOCCHIO', 4.0, 'Jakarta', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 4.0, 'Jinchang', Decimal('9.98')),
#  ('BANGER PINOCCHIO', 4.0, 'Katihar', Decimal('7.98')),
#  ('BANGER PINOCCHIO', 4.0, 'Tychy', Decimal('5.98')),
#  ('BANGER PINOCCHIO', 4.0, 'Vancouver', Decimal('1.98')),
#  ('BANGER PINOCCHIO', 4.0, 'Vicente Lpez', Decimal('1.98')),
#  ('BANG KWAI', 2.0, 'Torren', Decimal('7.98')),
#  ('BANG KWAI', 3.0, 'Coatzacoalcos', Decimal('7.98')),
#  ('BANG KWAI', 3.0, 'Pontianak', Decimal('5.98')),
#  ('BANG KWAI', 4.0, 'Boa Vista', Decimal('5.98')),
#  ('BANG KWAI', 4.0, 'Nagaon', Decimal('5.98')),
#  ('BANG KWAI', 4.0, 'Shikarpur', Decimal('5.98')),
#  ('BANG KWAI', 5.0, 'Taizz', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 1.0, 'Alvorada', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 1.0, 'Bucuresti', Decimal('11.98')),
#  ('BARBARELLA STREETCAR', 1.0, 'Kamakura', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 2.0, 'Ashdod', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 2.0, 'Cuernavaca', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 2.0, 'Ezeiza', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 2.0, 'Graz', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 2.0, 'Uruapan', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Abha', Decimal('9.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Bellevue', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Gandhinagar', Decimal('7.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Huixquilucan', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Ikerre', Decimal('7.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Maring', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Richmond Hill', Decimal('9.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Sal', Decimal('11.98')),
#  ('BARBARELLA STREETCAR', 3.0, 'Yuncheng', Decimal('11.98')),
#  ('BARBARELLA STREETCAR', 4.0, 'Hubli-Dharwad', Decimal('7.98')),
#  ('BARBARELLA STREETCAR', 4.0, 'Meixian', Decimal('11.98')),
#  ('BARBARELLA STREETCAR', 4.0, 'Miraj', Decimal('7.98')),
#  ('BARBARELLA STREETCAR', 4.0, 'Moscow', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 4.0, 'Niznekamsk', Decimal('7.98')),
#  ('BARBARELLA STREETCAR', 4.0, 'Qomsheh', Decimal('7.98')),
#  ('BARBARELLA STREETCAR', 4.0, 'South Hill', Decimal('5.98')),
#  ('BARBARELLA STREETCAR', 4.0, 'Tabriz', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 1.0, 'Juazeiro do Norte', Decimal('13.98')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Halifax', Decimal('9.98')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Jelets', Decimal('7.98')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Madiun', Decimal('7.98')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Basel', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Fukuyama', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Halisahar', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Kuwana', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Pontianak', Decimal('11.98')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Torren', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Adoni', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'al-Manama', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Guadalajara', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Haiphong', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Jastrzebie-Zdrj', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Kitwe', Decimal('9.98')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Le Mans', Decimal('5.98')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Ljubertsy', Decimal('5.98')),
#  ('BASIC EASY', 1.0, 'Tianjin', Decimal('5.98')),
#  ('BASIC EASY', 2.0, 'Shimoga', Decimal('5.98')),
#  ('BASIC EASY', 2.0, 'Sincelejo', Decimal('5.98')),
#  ('BASIC EASY', 3.0, 'Akishima', Decimal('7.98')),
#  ('BASIC EASY', 3.0, 'Bayugan', Decimal('11.98')),
#  ('BASIC EASY', 3.0, 'Escobar', Decimal('15.98')),
#  ('BASIC EASY', 3.0, 'Jurez', Decimal('7.98')),
#  ('BASIC EASY', 3.0, 'Konotop', Decimal('5.98')),
#  ('BASIC EASY', 3.0, 'Santiago de Compostela', Decimal('5.98')),
#  ('BASIC EASY', 3.0, 'Vancouver', Decimal('11.98')),
#  ('BASIC EASY', 3.0, 'Ziguinchor', Decimal('5.98')),
#  ('BASIC EASY', 4.0, 'Batman', Decimal('7.98')),
#  ('BASIC EASY', 4.0, 'Haining', Decimal('5.98')),
#  ('BASIC EASY', 4.0, 'Imus', Decimal('5.98')),
#  ('BASIC EASY', 4.0, 'Lubumbashi', Decimal('13.98')),
#  ('BASIC EASY', 4.0, 'Novi Sad', Decimal('5.98')),
#  ('BASIC EASY', 4.0, 'Pjatigorsk', Decimal('5.98')),
#  ('BASIC EASY', 4.0, 'Robamba', Decimal('7.98')),
#  ('BASIC EASY', 4.0, 'Santa Rosa', Decimal('15.98')),
#  ('BASIC EASY', 4.0, 'Simferopol', Decimal('13.98')),
#  ('BASIC EASY', 5.0, 'Laohekou', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 1.0, 'Almirante Brown', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 1.0, 'Katihar', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Cuautla', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Kilis', Decimal('9.98')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Novoterkassk', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Bijapur', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Caracas', Decimal('9.98')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Crdoba', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Hsichuh', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Quilmes', Decimal('7.98')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Sterling Heights', Decimal('11.98')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Kingstown', Decimal('11.98')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Lungtan', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Mysore', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Pathankot', Decimal('11.98')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Ruse', Decimal('5.98')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Xiangtan', Decimal('5.98')),
#  ('BEAR GRACELAND', 1.0, 'Pingxiang', Decimal('7.98')),
#  ('BEAR GRACELAND', 1.0, 'Tabuk', Decimal('13.98')),
#  ('BEAR GRACELAND', 1.0, 'Uijongbu', Decimal('5.98')),
#  ('BEAR GRACELAND', 2.0, 'Bchar', Decimal('5.98')),
#  ('BEAR GRACELAND', 2.0, 'Bhopal', Decimal('5.98')),
#  ('BEAR GRACELAND', 2.0, 'Nakhon Sawan', Decimal('11.98')),
#  ('BEAR GRACELAND', 2.0, 'South Hill', Decimal('5.98')),
#  ('BEAR GRACELAND', 3.0, 'Angra dos Reis', Decimal('15.98')),
#  ('BEAR GRACELAND', 3.0, 'Juazeiro do Norte', Decimal('15.98')),
#  ('BEAR GRACELAND', 3.0, 'Olomouc', Decimal('7.98')),
#  ('BEAR GRACELAND', 3.0, 'Pune', Decimal('11.98')),
#  ('BEAR GRACELAND', 3.0, 'Rio Claro', Decimal('9.98')),
#  ('BEAR GRACELAND', 3.0, 'Robamba', Decimal('13.98')),
#  ('BEAR GRACELAND', 3.0, 'Tiefa', Decimal('7.98')),
#  ('BEAR GRACELAND', 4.0, 'Addis Abeba', Decimal('5.98')),
#  ('BEAR GRACELAND', 4.0, 'Ahmadnagar', Decimal('13.98')),
#  ('BEAR GRACELAND', 4.0, 'Bhilwara', Decimal('5.98')),
#  ('BEAR GRACELAND', 4.0, 'Czestochowa', Decimal('9.98')),
#  ('BEAR GRACELAND', 4.0, 'Lapu-Lapu', Decimal('9.98')),
#  ('BEAR GRACELAND', 4.0, 'Liaocheng', Decimal('15.98')),
#  ('BEAR GRACELAND', 4.0, 'Mardan', Decimal('5.98')),
#  ('BEAR GRACELAND', 4.0, 'Shenzhen', Decimal('5.98')),
#  ('BEAST HUNCHBACK', 1.0, 'Jinzhou', Decimal('13.98')),
#  ('BEAST HUNCHBACK', 2.0, 'Faaa', Decimal('9.98')),
#  ('BEAST HUNCHBACK', 2.0, 'Nanyang', Decimal('9.98')),
#  ('BEAST HUNCHBACK', 3.0, 'Duisburg', Decimal('9.98')),
#  ('BEAST HUNCHBACK', 3.0, 'Omiya', Decimal('21.98')),
#  ('BEAST HUNCHBACK', 3.0, 'Sincelejo', Decimal('17.98')),
#  ('BEAST HUNCHBACK', 4.0, 'Chandrapur', Decimal('9.98')),
#  ('BEAST HUNCHBACK', 4.0, 'Chiayi', Decimal('9.98')),
#  ('BEAST HUNCHBACK', 4.0, 'Guadalajara', Decimal('21.98')),
#  ('BEAST HUNCHBACK', 4.0, 'Kolpino', Decimal('15.98')),
#  ('BEAST HUNCHBACK', 4.0, 'Zaoyang', Decimal('11.98')),
#  ('BEAUTY GREASE', 1.0, 'Denizli', Decimal('13.98')),
#  ('BEAUTY GREASE', 2.0, 'Barcelona', Decimal('9.98')),
#  ('BEAUTY GREASE', 2.0, 'Daugavpils', Decimal('17.98')),
#  ('BEAUTY GREASE', 2.0, 'Huixquilucan', Decimal('9.98')),
#  ('BEAUTY GREASE', 3.0, 'Davao', Decimal('9.98')),
#  ('BEAUTY GREASE', 3.0, 'Firozabad', Decimal('9.98')),
#  ('BEAUTY GREASE', 3.0, 'Jaffna', Decimal('9.98')),
#  ('BEAUTY GREASE', 3.0, 'Kursk', Decimal('17.98')),
#  ('BEAUTY GREASE', 3.0, 'Lancaster', Decimal('17.98')),
#  ('BEAUTY GREASE', 3.0, 'Mwene-Ditu', Decimal('11.98')),
#  ('BEAUTY GREASE', 3.0, 'Richmond Hill', Decimal('9.98')),
#  ('BEAUTY GREASE', 3.0, 'Ziguinchor', Decimal('9.98')),
#  ('BEAUTY GREASE', 4.0, 'Acua', Decimal('9.98')),
#  ('BEAUTY GREASE', 4.0, 'Arlington', Decimal('9.98')),
#  ('BEAUTY GREASE', 4.0, 'Bhopal', Decimal('9.98')),
#  ('BEAUTY GREASE', 4.0, 'Dhule (Dhulia)', Decimal('15.98')),
#  ('BEAUTY GREASE', 4.0, 'Hsichuh', Decimal('9.98')),
#  ('BEAUTY GREASE', 4.0, 'Kamarhati', Decimal('13.98')),
#  ('BEAUTY GREASE', 4.0, 'Nezahualcyotl', Decimal('13.98')),
#  ('BEAUTY GREASE', 4.0, 'Omdurman', Decimal('9.98')),
#  ('BEAUTY GREASE', 4.0, 'Syktyvkar', Decimal('11.98')),
#  ('BEAUTY GREASE', 4.0, 'Zhezqazghan', Decimal('9.98')),
#  ('BEDAZZLED MARRIED', 1.0, 'Angra dos Reis', Decimal('3.98')),
#  ('BEDAZZLED MARRIED', 2.0, 'Balurghat', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 2.0, 'Myingyan', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 3.0, 'Baybay', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 3.0, 'Duisburg', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 3.0, 'Le Mans', Decimal('3.98')),
#  ('BEDAZZLED MARRIED', 3.0, 'Naju', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 3.0, 'San Felipe de Puerto Plata', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 4.0, 'al-Manama', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 4.0, 'Binzhou', Decimal('3.98')),
#  ('BEDAZZLED MARRIED', 4.0, 'Naju', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 4.0, 'Serpuhov', Decimal('1.98')),
#  ('BEDAZZLED MARRIED', 4.0, 'Shanwei', Decimal('3.98')),
#  ('BED HIGHBALL', 3.0, 'Bhimavaram', Decimal('7.98')),
#  ('BED HIGHBALL', 3.0, 'Liaocheng', Decimal('5.98')),
#  ('BED HIGHBALL', 3.0, 'San Miguel de Tucumn', Decimal('5.98')),
#  ('BED HIGHBALL', 4.0, 'Iligan', Decimal('5.98')),
#  ('BED HIGHBALL', 4.0, 'Kursk', Decimal('11.98')),
#  ...]

# %% [markdown]
# # Conclusion

# %% [markdown]
# - We were able to show that a start schema is easier to understand
# - Evidence that is more performant

# %%
# !PGPASSWORD=student pg_dump -h 127.0.0.1 -U student pagila > Data/pagila-star.sql
